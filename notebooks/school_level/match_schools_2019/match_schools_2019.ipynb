# %%
import pandas as pd
import re

# %% [markdown]
# Create dataset for the corresponding year

# %%
# dataset = pd.read_csv('/Users/scipyguru/Library/Mobile Documents/com~apple~CloudDocs/Documents_New/NY fairness/NeurIPS/ZNO-Dataset/notebooks/students_level/zno_preprocessed.csv')
# dataset_grad = dataset[(dataset.regtypename == 'Випускник української школи поточного року') & (dataset.year == 2019)]
# dataset_schools = dataset_grad[['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']]
# dataset_schools_unique=dataset_schools.drop_duplicates()
# dataset_schools_unique.to_csv('schools2019.csv', index=False)

# %% [markdown]
# download dataset from EIE

# %%
eie_schools = pd.read_csv('schools2019.csv')

# %%
eie_schools.shape
# Out:
# (9574, 6)

# %%
eie_schools.eoregname
# Out:
# 0         Кіровоградська область
# 1               Донецька область
# 2            Хмельницька область
# 3       Дніпропетровська область
# 4             Рівненська область
#                   ...
# 9569           Вінницька область
# 9570             Одеська область
# 9571    Дніпропетровська область
# 9572         Житомирська область
# 9573       Тернопільська область
# Name: eoregname, Length: 9574, dtype: object

# %% [markdown]
# Create new column with region name and territory name in the format that matched with finance dataset

# %%
eie_schools['region'] = eie_schools.eoregname.str.split().str[0]
eie_schools['region'] = eie_schools['region'].str.replace('м.Київ', 'місто Київ')
eie_schools['tername'] = eie_schools.eoareaname.str.split().str[0]
eie_schools
# Out:
#                                                  eoname
# 0     Помічнянська загальноосвітня школа І-ІІІ ступе...  \
# 1     Володимирівська загальноосвітня школа I-III ст...
# 2     Балинський ліцей Смотрицької селищної ради Дун...
# 3     Комунальний заклад "Пушкарівська середня загал...
# 4     Вараська загальноосвітня школа І-ІІІ ступенів ...
# ...                                                 ...
# 9569  Загальноосвітня школа I-III ступенів с.Трибусі...
# 9570  Саратська вечірня (змінна)загальноосвітня школ...
# 9571  Комунальний заклад Зеленобалківський навчально...
# 9572  Липківська загальноосвітня школа І-ІІІ ступені...
# 9573  Висиповецький навчально-виховний комплекс "Заг...
#
#                          eotypename                 eoregname
# 0     середня загальноосвітня школа    Кіровоградська область  \
# 1     середня загальноосвітня школа          Донецька область
# 2                             ліцей       Хмельницька область
# 3     середня загальноосвітня школа  Дніпропетровська область
# 4     середня загальноосвітня школа        Рівненська область
# ...                             ...                       ...
# 9569  середня загальноосвітня школа         Вінницька область
# 9570         вечірня (змінна) школа           Одеська область
# 9571    навчально-виховний комплекс  Дніпропетровська область
# 9572  середня загальноосвітня школа       Житомирська область
# 9573  середня загальноосвітня школа     Тернопільська область
#
#                      eoareaname          eotername
# 0      Добровеличківський район          м.Помічна  \
# 1            Волноваський район  смт Володимирівка
# 2            Дунаєвецький район            с.Балин
# 3     Верхньодніпровський район       с.Пушкарівка
# 4                       м.Вараш            м.Вараш
# ...                         ...                ...
# 9569           Піщанський район       с.Трибусівка
# 9570           Саратський район         смт Сарата
# 9571         Широківський район     с.Зелена Балка
# 9572       Попільнянський район            с.Липки
# 9573          Зборівський район        с.Висипівці
#
#                                                eoparent            region
# 0     Відділ освіти виконавчого комітету Помічнянськ...    Кіровоградська  \
# 1     Управління освіти, сім'ї, молоді та спорту Вол...          Донецька
# 2     Відділ освіти, охорони здоров’я, культури, мол...       Хмельницька
# 3     Відділ освіти Верхньодніпровської райдержадмін...  Дніпропетровська
# 4     Управління освіти виконавчого комітету Вараськ...        Рівненська
# ...                                                 ...               ...
# 9569  Відділ освіти Піщанської районної державної ад...         Вінницька
# 9570  Управління освіти, сім'ї, молоді та спорту Сар...           Одеська
# 9571  Відділ освіти виконавчого комітету Новолатівсь...  Дніпропетровська
# 9572  Відділ освіти, охорони здоров'я, культури, мол...       Житомирська
# 9573  Відділ освіти Зборівської районної державної а...     Тернопільська
#
#                   tername
# 0      Добровеличківський
# 1            Волноваський
# 2            Дунаєвецький
# 3     Верхньодніпровський
# 4                 м.Вараш
# ...                   ...
# 9569           Піщанський
# 9570           Саратський
# 9571         Широківський
# 9572       Попільнянський
# 9573          Зборівський
#
# [9574 rows x 8 columns]

# %% [markdown]
# download finance dataset

# %%
finance_schools = pd.read_excel('/Users/scipyguru/Library/Mobile Documents/com~apple~CloudDocs/Documents_New/NY fairness/NeurIPS/ZNO-Dataset/notebooks/school_level/fin_data/ZZSO-2019.xlsx', header = 1)

# %%
finance_schools.head()
# Out:
#    № Області    Область Тип школи: міська / сільська  №№
# 0          2  Вінницька                        місто   1  \
# 1          2  Вінницька                        місто   2
# 2          2  Вінницька                        місто   3
# 3          2  Вінницька                        місто   4
# 4          2  Вінницька                        місто   5
#
#       Назва тер. Одиниці                               Найменування закладу
# 0  Жмеринська міська ОТГ  Загальноосвітня школа І-ІІІ ступенів №1 комуна...  \
# 1  Жмеринська міська ОТГ  Навчально-виховний комплекс "Загальноосвітня ш...
# 2  Жмеринська міська ОТГ  Загальноосвітня школа І-ІІІ ступенів №3 комуна...
# 3  Жмеринська міська ОТГ  Загальноосвітня школа I-III ступенів №4 комуна...
# 4  Жмеринська міська ОТГ  Навчально - виховний комплекс "Загальноосвітня...
#
#   Ступінь закладу ( I, I-II, I-III)
# 0                             I-III  \
# 1                             I-III
# 2                             I-III
# 3                             I-III
# 4                             I-III
#
#    Загальна площа приміщень школи ( без господарських будівель) (кв.м.)
# 0                                                NaN                     \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Кількість штатних працівників педагогічного персоналу  разом
# 0                                               44.0             \
# 1                                               59.0
# 2                                               82.0
# 3                                               61.0
# 4                                               70.0
#
#    Кількість штатних працівників непедагогічного персоналу  разом  ...
# 0                                               20.0               ...  \
# 1                                               18.0               ...
# 2                                               23.0               ...
# 3                                               22.0               ...
# 4                                               23.0               ...
#
#    Видатки на функціонування закладу (загальний фонд), тис.грн.\n2019 рік (касові видатки)
# 0                                             9915.2                                        \
# 1                                            13692.2
# 2                                            16184.7
# 3                                            14321.9
# 4                                            15061.0
#
#    Видатки на функціонування закладу (загальний фонд), тис.грн.\n2020 рік (план)
# 0                                              11123                              \
# 1                                            13758.8
# 2                                            17254.2
# 3                                            14598.6
# 4                                            16011.5
#
#    Видатки на 1 учня, 2019, тис. грн.**
# 0                             18.395547  \
# 1                             16.300238
# 2                             16.498165
# 3                             16.770375
# 4                             17.431713
#
#    Видатки на 1 клас, тис. грн.** 2019 рік (каса)  Опорна  Код бюджету
# 0                                      495.760000      ні   2202100000  \
# 1                                      456.406667      ні   2202100000
# 2                                      449.575000      ні   2202100000
# 3                                      447.559375      ні   2202100000
# 4                                      456.393939      ні   2202100000
#
#    Форма власності  Код ДІСО    ЄДРПОУ Примітка
# 0       комунальна      8173  26244113      NaN
# 1       комунальна      8174  26244107      NaN
# 2       комунальна      8175  26244136      NaN
# 3       комунальна      8176  26244099      NaN
# 4       комунальна      8177  23064971      NaN
#
# [5 rows x 28 columns]

# %%
finance_schools.columns
# Out:
# Index(['№ Області', 'Область', 'Тип школи: міська / сільська', '№№',
#        'Назва тер. Одиниці', 'Найменування закладу',
#        'Ступінь закладу ( I, I-II, I-III)',
#        'Загальна площа приміщень школи ( без господарських будівель) (кв.м.)',
#        'Кількість штатних працівників педагогічного персоналу  разом',
#        'Кількість штатних працівників непедагогічного персоналу  разом',
#        'Кількість штатних працівників педагогічного персоналу  пенсійного віку',
#        'Питома вага непедагогічного персоналу у загальній кількості працівників, %**',
#        'Питома вага педагогічних працівників пенсійного віку у загальній кількості педагогічних працівників, %**',
#        'Кількість учнів разом',
#        'Разом кількість учнів, та дітей, які здобувають дошкільну освіту',
#        'Кількість класів разом',
#        'Фактична наповнюваність класів, учнів на клас**',
#        'Показник співвідношення кількості учнів на одного вчителя, учнів на вчителя**',
#        'Видатки на функціонування закладу (загальний фонд), тис.грн.\n2019 рік (касові видатки)',
#        'Видатки на функціонування закладу (загальний фонд), тис.грн.\n2020 рік (план)',
#        'Видатки на 1 учня, 2019, тис. грн.**',
#        'Видатки на 1 клас, тис. грн.** 2019 рік (каса)', 'Опорна',
#        'Код бюджету', 'Форма власності', 'Код ДІСО', 'ЄДРПОУ', 'Примітка'],
#       dtype='object')

# %% [markdown]
# choose columns that give information about schools

# %%
finance_schools = finance_schools[['Область', 'Назва тер. Одиниці', 'Найменування закладу']]

# %% [markdown]
# Rename columns using a dictionary

# %%
new_columns = {'Область': 'region', 'Назва тер. Одиниці': 'tername', 'Найменування закладу': 'schoolname'}
finance_schools = finance_schools.rename(columns=new_columns)

# %%
finance_schools
# Out:
#            region                tername
# 0       Вінницька  Жмеринська міська ОТГ  \
# 1       Вінницька  Жмеринська міська ОТГ
# 2       Вінницька  Жмеринська міська ОТГ
# 3       Вінницька  Жмеринська міська ОТГ
# 4       Вінницька  Жмеринська міська ОТГ
# ...           ...                    ...
# 14170  місто Київ             місто Київ
# 14171  місто Київ             місто Київ
# 14172  місто Київ             місто Київ
# 14173  місто Київ             місто Київ
# 14174  місто Київ             місто Київ
#
#                                               schoolname
# 0      Загальноосвітня школа І-ІІІ ступенів №1 комуна...
# 1      Навчально-виховний комплекс "Загальноосвітня ш...
# 2      Загальноосвітня школа І-ІІІ ступенів №3 комуна...
# 3      Загальноосвітня школа I-III ступенів №4 комуна...
# 4      Навчально - виховний комплекс "Загальноосвітня...
# ...                                                  ...
# 14170                              Школа І ступеня № 326
# 14171    Школа І ступеня №333 Дарницького району м.Києва
# 14172   Початкова школа №332 Дарницького району м. Києва
# 14173  Початкова школа № 334 Дарницького району м. Києва
# 14174  Коледж хореографічного мистецтва "Київська мун...
#
# [14175 rows x 3 columns]

# %%
finance_schools.shape
# Out:
# (14175, 3)

# %%
eie_schools.shape
# Out:
# (9574, 8)

# %%
df = pd.DataFrame(columns=['eoname', 'schoolname', 'regname'])
df
# Out:
# Empty DataFrame
# Columns: [eoname, schoolname, regname]
# Index: []

# %% [markdown]
# check for duplicates by the name of school

# %%
eie_schools[eie_schools.eoname.duplicated(keep=False)].sort_values('eoname')
# Out:
#                                                  eoname
# 4390   Березівська загальноосвітня школа I-III ступенів  \
# 4443   Березівська загальноосвітня школа I-III ступенів
# 7743   Березівська загальноосвітня школа I-III ступенів
# 4051  Варварівська загальноосвітня школа I-III ступенів
# 7129  Варварівська загальноосвітня школа I-III ступенів
# 9190   Вільшанська загальноосвітня школа I-III ступенів
# 7069   Вільшанська загальноосвітня школа I-III ступенів
# 9485  Красносільська загальноосвітня школа I-III сту...
# 4572  Красносільська загальноосвітня школа I-III сту...
# 8794    Озерянська загальноосвітня школа І-ІІІ ступенів
# 1417    Озерянська загальноосвітня школа І-ІІІ ступенів
# 5739   П'ятківська загальноосвітня школа I-III ступенів
# 6895   П'ятківська загальноосвітня школа I-III ступенів
# 7390   Писарівська загальноосвітня школа I-III ступенів
# 6613   Писарівська загальноосвітня школа I-III ступенів
# 8466     Яланецька загальноосвітня школа I-III ступенів
# 2233     Яланецька загальноосвітня школа I-III ступенів
#
#                          eotypename              eoregname
# 4390  середня загальноосвітня школа    Житомирська область  \
# 4443  середня загальноосвітня школа    Житомирська область
# 7743  середня загальноосвітня школа    Хмельницька область
# 4051  середня загальноосвітня школа    Житомирська область
# 7129  середня загальноосвітня школа    Житомирська область
# 9190  середня загальноосвітня школа    Житомирська область
# 7069  середня загальноосвітня школа    Житомирська область
# 9485  середня загальноосвітня школа    Житомирська область
# 4572  середня загальноосвітня школа      Вінницька область
# 8794  середня загальноосвітня школа  Тернопільська область
# 1417  середня загальноосвітня школа  Тернопільська область
# 5739  середня загальноосвітня школа    Житомирська область
# 6895  середня загальноосвітня школа      Вінницька область
# 7390  середня загальноосвітня школа    Хмельницька область
# 6613  середня загальноосвітня школа      Вінницька область
# 8466  середня загальноосвітня школа      Вінницька область
# 2233  середня загальноосвітня школа      Вінницька область
#
#                 eoareaname      eotername
# 4390      Любарський район    с.Березівка  \
# 4443    Житомирський район    с.Березівка
# 7743    Новоушицький район    с.Березівка
# 4051   Ємільчинський район   с.Варварівка
# 7129       Олевський район   с.Варварівка
# 9190    Романівський район       с.Вільха
# 7069     Чуднівський район    с.Вільшанка
# 9485     Чуднівський район  с.Красносілка
# 4572     Бершадський район  с.Красносілка
# 8794     Борщівський район      с.Озеряни
# 1417       Бучацький район      с.Озеряни
# 5739     Чуднівський район       с.П'ятка
# 6895     Бершадський район    с.П'ятківка
# 7390     Волочиський район    с.Писарівка
# 6613      Вінницький район    с.Писарівка
# 8466     Бершадський район      с.Яланець
# 2233  Томашпільський район      с.Яланець
#
#                                                eoparent         region
# 4390  Відділ освіти, молоді та спорту Любарської сел...    Житомирська  \
# 4443  Відділ освіти Житомирської районної державної ...    Житомирська
# 7743  Відділ освіти, молоді та спорту Новоушицької с...    Хмельницька
# 4051  Відділ освіти Ємільчинської районної державної...    Житомирська
# 7129  Відділ освіти, молоді та спорту Олевської місь...    Житомирська
# 9190  Відділ освіти Романівської районної державної ...    Житомирська
# 7069  Відділ освіти Чуднівської районної державної а...    Житомирська
# 9485  Відділ освіти Чуднівської районної державної а...    Житомирська
# 4572  Відділ освіти, фізичної культури та спорту Бер...      Вінницька
# 8794  Відділ освіти та соціально-культурної сфери Оз...  Тернопільська
# 1417  Відділ освіти Бучацької районної державної адм...  Тернопільська
# 5739  Відділ освіти Чуднівської районної державної а...    Житомирська
# 6895  Відділ освіти, фізичної культури та спорту Бер...      Вінницька
# 7390  Відділ освіти, молоді та спорту, культури та т...    Хмельницька
# 6613  Відділ освіти Вінницької районної державної ад...      Вінницька
# 8466  Відділ освіти, фізичної культури та спорту Бер...      Вінницька
# 2233  Відділ освіти Томашпільської районної державно...      Вінницька
#
#              tername
# 4390      Любарський
# 4443    Житомирський
# 7743    Новоушицький
# 4051   Ємільчинський
# 7129       Олевський
# 9190    Романівський
# 7069     Чуднівський
# 9485     Чуднівський
# 4572     Бершадський
# 8794     Борщівський
# 1417       Бучацький
# 5739     Чуднівський
# 6895     Бершадський
# 7390     Волочиський
# 6613      Вінницький
# 8466     Бершадський
# 2233  Томашпільський

# %%
finance_schools[finance_schools.schoolname.duplicated(keep=False)]
# Out:
#               region                   tername
# 2838     Житомирська       Черняхівський район  \
# 3096     Житомирська  Соколівська сільська ОТГ
# 7289       Львівська     Рудківська міська ОТГ
# 9608      Рівненська   Демидівська селищна ОТГ
# 10087  Тернопільська           Бучацький район
# 10495  Тернопільська   Озерянська сільська ОТГ
#
#                                              schoolname
# 2838   Андріївська загальноосвітня школа І-ІІІ ступенів
# 3096   Андріївська загальноосвітня школа І-ІІІ ступенів
# 7289                                Рудківська гімназія
# 9608                                Рудківська гімназія
# 10087   Озерянська загальноосвітня школа І-ІІІ ступенів
# 10495   Озерянська загальноосвітня школа І-ІІІ ступенів

# %% [markdown]
# resolving duplicates

# %%
eie_schools.loc[1417, 'eoname'] = eie_schools.loc[1417, 'eoname']+ 'Бучацького'
finance_schools.loc[10087, 'schoolname'] = finance_schools.loc[10087, 'schoolname']+ 'Бучацького'

# %%
eie_schools_temp = eie_schools
finance_schools_temp = finance_schools

# %%
for region in sorted(eie_schools.region.unique()):
    for eoname in eie_schools[eie_schools.region == region].eoname:
        if eoname in finance_schools[finance_schools.region == region].schoolname.unique():
            df = pd.concat([df, pd.DataFrame([{'eoname': eoname, 'schoolname': eoname, 'regname': region}])], ignore_index=True)
            eie_schools_temp = eie_schools_temp[eie_schools_temp.eoname != eoname]
            finance_schools_temp = finance_schools_temp[finance_schools_temp.schoolname != eoname]

df
# Out:
#                                                  eoname
# 0     Рогатинський ліцей №1 Рогатинської районної ра...  \
# 1     Калуський ліцей №10 Калуської міської ради Іва...
# 2     Загвіздянський ліцей Загвіздянської сільської ...
# 3     Великоключівський ліцей Нижньовербізької сільс...
# 4     Яремчанська загальноосвітня школа І-ІІІ ступен...
# ...                                                 ...
# 2204  Спеціалізована школа І-ІІІ ступенів №234 м.Киє...
# 2205              Школа І-ІІІ ступенів №108 міста Києва
# 2206  Спеціалізована школа І-ІІІ ступенів № 277 з по...
# 2207         Еколого-природничий ліцей №116 міста Києва
# 2208         Середня загальноосвітня школа №229 м.Києва
#
#                                              schoolname            regname
# 0     Рогатинський ліцей №1 Рогатинської районної ра...  Івано-Франківська
# 1     Калуський ліцей №10 Калуської міської ради Іва...  Івано-Франківська
# 2     Загвіздянський ліцей Загвіздянської сільської ...  Івано-Франківська
# 3     Великоключівський ліцей Нижньовербізької сільс...  Івано-Франківська
# 4     Яремчанська загальноосвітня школа І-ІІІ ступен...  Івано-Франківська
# ...                                                 ...                ...
# 2204  Спеціалізована школа І-ІІІ ступенів №234 м.Киє...         місто Київ
# 2205              Школа І-ІІІ ступенів №108 міста Києва         місто Київ
# 2206  Спеціалізована школа І-ІІІ ступенів № 277 з по...         місто Київ
# 2207         Еколого-природничий ліцей №116 міста Києва         місто Київ
# 2208         Середня загальноосвітня школа №229 м.Києва         місто Київ
#
# [2209 rows x 3 columns]

# %% [markdown]
# control the number of rows added and removed

# %%
print(eie_schools.shape[0]-eie_schools_temp.shape[0])
print(finance_schools.shape[0] - finance_schools_temp.shape[0])
print(df.shape[0])
# Out:
# 2209
# 2209
# 2209

# %% [markdown]
# Creating id from school's name

# %%
eie_schools_temp['id'] = eie_schools_temp['eoname']
eie_schools_temp['id'] = eie_schools_temp['id'].str.replace('[\s]', '', regex = True)
eie_schools_temp.loc[eie_schools_temp['id'].str.endswith('обл'), 'id'] = eie_schools_temp.loc[eie_schools_temp['id'].str.endswith('обл'), 'id'] + '.'
eie_schools_temp['id'] = eie_schools_temp['id'].str.replace('І', 'I')
eie_schools_temp['id'] = eie_schools_temp['id'].str.replace('I-III', '3')
eie_schools_temp['id'] = eie_schools_temp['id'].str.replace('I-II', '2')
eie_schools_temp['id'] = eie_schools_temp['id'].str.lower()

dct = {'с.':'села', 'ст.':'ступенів', 'ім.':'імені', 'iм.':'імені', 'обл.': 'області', 
       '||||':'3', '|||':'2',
       'i':'', 'і':'', 'ї':'', 'o':'о', 'y':'у', 'p':'р', 'c':'с', 'ґ':'г', 'e':'е', 'a':'а', 'k':'к', 'x': 'х',
       "'":'', "’":'', ",":'', ".":'', "«":'', "»":'', "–":'', "-":'', 
       "_x000d_":'', '_x000D_':'', "_":'', "(":'', ")":'', "[":'', "]":'', "}":'', "{":'', 
       "нвк":'навчальновиховнийкомплекс', 'знз': 'загальноосвтнйнавчальнийзаклад', 'нн':'н', 'днз': 'дошкльнийнавчальнийзаклад'}

for symb in dct:
    eie_schools_temp['id'] = eie_schools_temp['id'].str.replace(symb, dct[symb])

eie_schools_temp['id'] = eie_schools_temp['id'].str.replace('"', '', regex = True)

# %%
eie_schools_temp.head(10)
# Out:
#                                                eoname
# 0   Помічнянська загальноосвітня школа І-ІІІ ступе...  \
# 1   Володимирівська загальноосвітня школа I-III ст...
# 3   Комунальний заклад "Пушкарівська середня загал...
# 4   Вараська загальноосвітня школа І-ІІІ ступенів ...
# 5   Мукачівська загальноосвітня школа І-ІІІ ступен...
# 6   Чернігівська загальноосвітня школа I-III ступе...
# 7   Харківська загальноосвітня школа I-III ступені...
# 8   Спеціалізована школа І-ІІІ ступенів № 152 з по...
# 12  Ірпінська загальноосвітня школа І-ІІІ ступенів...
# 13  Вознесенська загальноосвітня школа I-III ступе...
#
#                        eotypename                 eoregname
# 0   середня загальноосвітня школа    Кіровоградська область  \
# 1   середня загальноосвітня школа          Донецька область
# 3   середня загальноосвітня школа  Дніпропетровська область
# 4   середня загальноосвітня школа        Рівненська область
# 5   середня загальноосвітня школа      Закарпатська область
# 6   середня загальноосвітня школа      Чернігівська область
# 7   середня загальноосвітня школа        Харківська область
# 8            спеціалізована школа                    м.Київ
# 12  середня загальноосвітня школа          Київська область
# 13  середня загальноосвітня школа      Миколаївська область
#
#                                 eoareaname                   eotername
# 0                 Добровеличківський район                   м.Помічна  \
# 1                       Волноваський район           смт Володимирівка
# 3                Верхньодніпровський район                с.Пушкарівка
# 4                                  м.Вараш                     м.Вараш
# 5                               м.Мукачево                  м.Мукачево
# 6   м.Чернігів. Новозаводський район міста  Новозаводський район міста
# 7        м.Харків. Московський район міста     Московський район міста
# 8          м.Київ. Деснянський район міста     Деснянський район міста
# 12                                м.Ірпінь                    м.Ірпінь
# 13                           м.Вознесенськ               м.Вознесенськ
#
#                                              eoparent            region
# 0   Відділ освіти виконавчого комітету Помічнянськ...    Кіровоградська  \
# 1   Управління освіти, сім'ї, молоді та спорту Вол...          Донецька
# 3   Відділ освіти Верхньодніпровської райдержадмін...  Дніпропетровська
# 4   Управління освіти виконавчого комітету Вараськ...        Рівненська
# 5   Управління освіти, молоді та спорту виконавчог...      Закарпатська
# 6        Управління освіти Чернігівської міської ради      Чернігівська
# 7   Управління освіти адміністрації Московського р...        Харківська
# 8   Управління освіти Деснянської районної в місті...        місто Київ
# 12  Управління освіти і науки Ірпінської міської р...          Київська
# 13       Управління освіти Вознесенської міської ради      Миколаївська
#
#                 tername                                                 id
# 0    Добровеличківський  помчнянськазагальноосвтняшкола3ступенв№1менгер...
# 1          Волноваський  володимирвськазагальноосвтняшкола3ступенв№1вол...
# 3   Верхньодніпровський  комунальнийзакладпушкарвськасереднязагальноосв...
# 4               м.Вараш  вараськазагальноосвтняшкола3ступенв№2вараськом...
# 5            м.Мукачево  мукачвськазагальноосвтняшкола3ступенв№1меносел...
# 6           м.Чернігів.  чернгвськазагальноосвтняшкола3ступенв№13чернгв...
# 7             м.Харків.  харквськазагальноосвтняшкола3ступенв№138харквс...
# 8               м.Київ.  спецалзованашкола3ступенв№152зпоглибленимвивче...
# 12             м.Ірпінь  рпнськазагальноосвтняшкола3ступенв№17рпнськомс...
# 13        м.Вознесенськ  вознесенськазагальноосвтняшкола3ступенв№10возн...

# %%
finance_schools_temp['id'] = finance_schools_temp.schoolname
finance_schools_temp['id'] = finance_schools_temp['id'].str.replace('[\s]', '', regex = True)
finance_schools_temp.loc[finance_schools_temp['id'].str.endswith('обл'), 'id'] = finance_schools_temp.loc[finance_schools_temp['id'].str.endswith('обл'), 'id'] + '.'
finance_schools_temp['id'] = finance_schools_temp['id'].str.replace('І', 'I')
finance_schools_temp['id'] = finance_schools_temp['id'].str.replace('I-III', '3')
finance_schools_temp['id'] = finance_schools_temp['id'].str.replace('I-II', '2')
finance_schools_temp['id'] = finance_schools_temp['id'].str.lower()

dct = {'с.':'села', 'ст.':'ступенів', 'ім.':'імені', 'iм.':'імені', 'обл.': 'області', 
       '||||':'3', '|||':'2',
       'i':'', 'і':'', 'ї':'', 'o':'о', 'y':'у', 'p':'р', 'c':'с', 'ґ':'г', 'e':'е', 'a':'а', 'k':'к', 'x': 'х',
       "'":'', "’":'', ",":'', ".":'', "«":'', "»":'', "–":'', "-":'', 
       "_x000d_":'', '_x000D_':'', "_":'', "(":'', ")":'', "[":'', "]":'', "}":'', "{":'', 
       "нвк":'навчальновиховнийкомплекс', 'знз': 'загальноосвтнйнавчальнийзаклад', 'нн':'н', 'днз': 'дошкльнийнавчальнийзаклад'}

for symb in dct:
    finance_schools_temp['id'] = finance_schools_temp['id'].str.replace(symb, dct[symb])

finance_schools_temp['id'] = finance_schools_temp['id'].str.replace('"', '', regex = True)
finance_schools_temp.head()
# Out:
#       region                tername
# 0  Вінницька  Жмеринська міська ОТГ  \
# 1  Вінницька  Жмеринська міська ОТГ
# 2  Вінницька  Жмеринська міська ОТГ
# 3  Вінницька  Жмеринська міська ОТГ
# 4  Вінницька  Жмеринська міська ОТГ
#
#                                           schoolname
# 0  Загальноосвітня школа І-ІІІ ступенів №1 комуна...  \
# 1  Навчально-виховний комплекс "Загальноосвітня ш...
# 2  Загальноосвітня школа І-ІІІ ступенів №3 комуна...
# 3  Загальноосвітня школа I-III ступенів №4 комуна...
# 4  Навчально - виховний комплекс "Загальноосвітня...
#
#                                                   id
# 0  загальноосвтняшкола3ступенв№1комунальновласнос...
# 1  навчальновиховнийкомплексзагальноосвтняшкола3с...
# 2  загальноосвтняшкола3ступенв№3комунальновласнос...
# 3  загальноосвтняшкола3ступенв№4комунальновластно...
# 4  навчальновиховнийкомплексзагальноосвтняшкола3с...

# %% [markdown]
# check duplicates inside regions of interest for both datasets

# %%
for region in sorted(eie_schools_temp.region.unique()):
    region_school = eie_schools_temp[eie_schools_temp.region == region]
    region_finance = finance_schools_temp[finance_schools_temp.region == region]
    for id in region_school.id:
        if id in region_finance.id.unique():
            if len(region_school[region_school.id == id]) > 1 or len(region_finance[region_finance.id == id]) > 1:
                print('eie')
                display(region_school[region_school.id == id])
                print('finance')
                display(region_finance[region_finance.id == id])
# Out:
# eie
#                                               eoname
# 2233  Яланецька загальноосвітня школа I-III ступенів  \
# 8466  Яланецька загальноосвітня школа I-III ступенів
#
#                          eotypename          eoregname            eoareaname
# 2233  середня загальноосвітня школа  Вінницька область  Томашпільський район  \
# 8466  середня загальноосвітня школа  Вінницька область     Бершадський район
#
#       eotername                                           eoparent     region
# 2233  с.Яланець  Відділ освіти Томашпільської районної державно...  Вінницька  \
# 8466  с.Яланець  Відділ освіти, фізичної культури та спорту Бер...  Вінницька
#
#              tername                                    id
# 2233  Томашпільський  яланецьказагальноосвтняшкола3ступенв
# 8466     Бершадський  яланецьказагальноосвтняшкола3ступенв
# finance
#        region            tername
# 59  Вінницька  Бершадський район  \
#
#                                         schoolname
# 59  Яланецька загальноосвітня школа І-ІІІ ступенів  \
#
#                                       id
# 59  яланецьказагальноосвтняшкола3ступенв
# eie
#                                               eoname
# 2233  Яланецька загальноосвітня школа I-III ступенів  \
# 8466  Яланецька загальноосвітня школа I-III ступенів
#
#                          eotypename          eoregname            eoareaname
# 2233  середня загальноосвітня школа  Вінницька область  Томашпільський район  \
# 8466  середня загальноосвітня школа  Вінницька область     Бершадський район
#
#       eotername                                           eoparent     region
# 2233  с.Яланець  Відділ освіти Томашпільської районної державно...  Вінницька  \
# 8466  с.Яланець  Відділ освіти, фізичної культури та спорту Бер...  Вінницька
#
#              tername                                    id
# 2233  Томашпільський  яланецьказагальноосвтняшкола3ступенв
# 8466     Бершадський  яланецьказагальноосвтняшкола3ступенв
# finance
#        region            tername
# 59  Вінницька  Бершадський район  \
#
#                                         schoolname
# 59  Яланецька загальноосвітня школа І-ІІІ ступенів  \
#
#                                       id
# 59  яланецьказагальноосвтняшкола3ступенв
# eie
#                                                 eoname
# 6708  Андріївська загальноосвітня школа I-III ступенів  \
#
#                          eotypename            eoregname        eoareaname
# 6708  середня загальноосвітня школа  Житомирська область  Пулинський район  \
#
#         eotername                                           eoparent
# 6708  с.Андріївка  Відділ освіти, культури та соціального захисту...  \
#
#            region     tername                                    id
# 6708  Житомирська  Пулинський  андрвськазагальноосвтняшкола3ступенв
# finance
#            region                   tername
# 2838  Житомирська       Черняхівський район  \
# 3096  Житомирська  Соколівська сільська ОТГ
#
#                                             schoolname
# 2838  Андріївська загальноосвітня школа І-ІІІ ступенів  \
# 3096  Андріївська загальноосвітня школа І-ІІІ ступенів
#
#                                         id
# 2838  андрвськазагальноосвтняшкола3ступенв
# 3096  андрвськазагальноосвтняшкола3ступенв
# eie
#                                                  eoname
# 8589  ІІ-Іванівська загальноосвітня школа I-III ступ...  \
#
#                          eotypename           eoregname            eoareaname
# 8589  середня загальноосвітня школа  Харківська область  Барвінківський район  \
#
#           eotername                                           eoparent
# 8589  с-ще Іванівка  Відділ освіти Барвінківської районної державно...  \
#
#           region         tername
# 8589  Харківська  Барвінківський  \
#
#                                                      id
# 8589  ванвськазагальноосвтняшкола3ступенвбарвнквсько...
# finance
#            region               tername
# 10968  Харківська  Барвінківський район  \
# 10969  Харківська  Барвінківський район
#
#                                               schoolname
# 10968  І-Іванівська загальноосвітня школа І-ІІІ ступе...  \
# 10969  ІІ-Іванівська загальноосвітня школа І-ІІІ ступ...
#
#                                                       id
# 10968  ванвськазагальноосвтняшкола3ступенвбарвнквсько...
# 10969  ванвськазагальноосвтняшкола3ступенвбарвнквсько...

# %% [markdown]
# resolving duplicates

# %%
eie_schools_temp.loc[8466, 'id'] = 'бер' +eie_schools_temp.loc[8466, 'id']
finance_schools_temp.loc[59, 'id'] = 'бер'+finance_schools_temp.loc[59, 'id']
eie_schools_temp.loc[6708, 'id'] = 'чер' +eie_schools_temp.loc[6708, 'id']
finance_schools_temp.loc[2838, 'id'] = 'чер'+finance_schools_temp.loc[2838, 'id']
eie_schools_temp.loc[8589, 'id'] = 'II' +eie_schools_temp.loc[8589, 'id']
finance_schools_temp.loc[10969	, 'id'] = 'II'+finance_schools_temp.loc[10969	, 'id']

# %% [markdown]
# checking again

# %%
for region in sorted(eie_schools_temp.region.unique()):
    region_school = eie_schools_temp[eie_schools_temp.region == region]
    region_finance = finance_schools_temp[finance_schools_temp.region == region]
    for id in region_school.id:
        if id in region_finance.id.unique():
            if len(region_school[region_school.id == id]) > 1 or len(region_finance[region_finance.id == id]) > 1:
                print('data')
                display(region_school[region_school.id == id])
                print('finance')
                display(region_finance[region_finance.id == id])

# %%
eie_schools_temp1 = eie_schools_temp
finance_schools_temp1 = finance_schools_temp

# %% [markdown]
# matching by id

# %%
for region in sorted(eie_schools_temp.region.unique()):
    region_school = eie_schools_temp[eie_schools_temp.region == region]
    region_finance = finance_schools_temp[finance_schools_temp.region == region]
    for id in region_school.id:
        if id in region_finance.id.unique():
            df = pd.concat([df, pd.DataFrame([{'eoname': eie_schools_temp.loc[eie_schools_temp.id == id, 'eoname'].iloc[0], 
                                               'schoolname': finance_schools_temp.loc[finance_schools_temp.id == id, 'schoolname'].iloc[0],
                                               'regname': region}])], ignore_index=True)
            eie_schools_temp1 = eie_schools_temp1[~((eie_schools_temp1.region == region) & (eie_schools_temp1.id == id))]
            finance_schools_temp1 = finance_schools_temp1[~((finance_schools_temp1.region == region) & (finance_schools_temp1.id == id))]

df.shape
# Out:
# (6078, 3)

# %%
print(eie_schools.shape[0]-eie_schools_temp1.shape[0])
print(finance_schools.shape[0] - finance_schools_temp1.shape[0])
print(df.shape[0])
# Out:
# 6078
# 6078
# 6078

# %%
df
# Out:
#                                                  eoname
# 0     Рогатинський ліцей №1 Рогатинської районної ра...  \
# 1     Калуський ліцей №10 Калуської міської ради Іва...
# 2     Загвіздянський ліцей Загвіздянської сільської ...
# 3     Великоключівський ліцей Нижньовербізької сільс...
# 4     Яремчанська загальноосвітня школа І-ІІІ ступен...
# ...                                                 ...
# 6073  Спеціалізована школа І-ІІІ ступенів з поглибле...
# 6074  Спеціалізована школа І-ІІІ ступенів з поглибле...
# 6075  Школа І-ІІІ ступенів № 147 Деснянського району...
# 6076  Спеціалізована школа І-ІІІ ступенів з поглибле...
# 6077  Спеціалізована школа І-ІІІ ступенів з поглибле...
#
#                                              schoolname            regname
# 0     Рогатинський ліцей №1 Рогатинської районної ра...  Івано-Франківська
# 1     Калуський ліцей №10 Калуської міської ради Іва...  Івано-Франківська
# 2     Загвіздянський ліцей Загвіздянської сільської ...  Івано-Франківська
# 3     Великоключівський ліцей Нижньовербізької сільс...  Івано-Франківська
# 4     Яремчанська загальноосвітня школа І-ІІІ ступен...  Івано-Франківська
# ...                                                 ...                ...
# 6073  Спеціалізована школа І-ІІІ ступенів з поглибле...         місто Київ
# 6074  Спеціалізована школа І-ІІІ ступенів з поглибле...         місто Київ
# 6075  школа І-ІІІ ступенів № 147 Деснянського району...         місто Київ
# 6076  Спеціалізована школа І-ІІІ ступенів з поглибле...         місто Київ
# 6077  спеціалізована школа І-ІІІ ступенів з поглибле...         місто Київ
#
# [6078 rows x 3 columns]

# %% [markdown]
# matching by id trimming to the length of the other id

# %%
eie_schools_temp2 = eie_schools_temp1
finance_schools_temp2 = finance_schools_temp1

# %%
(eie_schools.shape[0]-eie_schools_temp2.shape[0]) == (finance_schools.shape[0]-finance_schools_temp2.shape[0])
# Out:
# True

# %%
for region in sorted(eie_schools_temp1.region.unique()):
    region_schools = eie_schools_temp1[eie_schools_temp1.region == region]
    region_finance = finance_schools_temp1[finance_schools_temp1.region == region]
    for id in region_schools.id:
        if (id in region_finance.id.str[:len(id)].unique()) and \
             re.findall(r'№(\d+)', region_schools.loc[region_schools.id == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id.str[:len(id)] == id, 'schoolname'].iloc[0]):
            if len(region_schools[region_schools.id == id])>1 or len(region_finance[region_finance.id.str[:len(id)] == id]) >1:
                print('eie')
                display(region_schools[region_schools.id == id])
                print('finance')
                display(region_finance[region_finance.id.str[:len(id)] == id])
# Out:
# eie
#                                                  eoname
# 4520  Костянтинівський заклад загальної середньої ос...  \
#
#                          eotypename         eoregname       eoareaname
# 4520  середня загальноосвітня школа  Донецька область  м.Костянтинівка  \
#
#             eotername                                           eoparent
# 4520  м.Костянтинівка  Управління освіти міської ради м.Костянтинівки...  \
#
#         region          tername
# 4520  Донецька  м.Костянтинівка  \
#
#                                                      id
# 4520  костянтинвськийзакладзагальносередньоосвти3сту...
# finance
#         region              tername
# 2194  Донецька  місто Костянтинівка  \
# 2196  Донецька  місто Костянтинівка
#
#                                              schoolname
# 2194  Костянтинівський заклад загальної середньої ос...  \
# 2196  Костянтинівський заклад загальної середньої ос...
#
#                                                      id
# 2194  костянтинвськийзакладзагальносередньоосвти3сту...
# 2196  костянтинвськийзакладзагальносередньоосвти3сту...
# eie
#                                                  eoname
# 4051  Варварівська загальноосвітня школа I-III ступенів  \
# 7129  Варварівська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname           eoareaname
# 4051  середня загальноосвітня школа  Житомирська область  Ємільчинський район  \
# 7129  середня загальноосвітня школа  Житомирська область      Олевський район
#
#          eotername                                           eoparent
# 4051  с.Варварівка  Відділ освіти Ємільчинської районної державної...  \
# 7129  с.Варварівка  Відділ освіти, молоді та спорту Олевської місь...
#
#            region        tername                                      id
# 4051  Житомирська  Ємільчинський  варварвськазагальноосвтняшкола3ступенв
# 7129  Житомирська      Олевський  варварвськазагальноосвтняшкола3ступенв
# finance
#            region              tername
# 2690  Житомирська  Ємільчинський район  \
# 2907  Житомирська  Олевська міська ОТГ
#
#                                              schoolname
# 2690  Варварівська загальноосвітня школа І-ІІІ ступе...  \
# 2907  Варварівська загальноосвітня школа І - ІІІ сту...
#
#                                                      id
# 2690  варварвськазагальноосвтняшкола3ступенвємльчинс...
# 2907  варварвськазагальноосвтняшкола3ступенволевсько...
# eie
#                                                 eoname
# 4390  Березівська загальноосвітня школа I-III ступенів  \
# 4443  Березівська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname          eoareaname
# 4390  середня загальноосвітня школа  Житомирська область    Любарський район  \
# 4443  середня загальноосвітня школа  Житомирська область  Житомирський район
#
#         eotername                                           eoparent
# 4390  с.Березівка  Відділ освіти, молоді та спорту Любарської сел...  \
# 4443  с.Березівка  Відділ освіти Житомирської районної державної ...
#
#            region       tername                                     id
# 4390  Житомирська    Любарський  березвськазагальноосвтняшкола3ступенв
# 4443  Житомирська  Житомирський  березвськазагальноосвтняшкола3ступенв
# finance
#            region                tername
# 2699  Житомирська     Житомирський район  \
# 3044  Житомирська  Любарська селищна ОТГ
#
#                                              schoolname
# 2699  Березівська загальноосвітня школа І - ІІІ ступ...  \
# 3044  Березівська загальноосвітня школа І-ІІІ ступен...
#
#                                                      id
# 2699  березвськазагальноосвтняшкола3ступенвжитомирсь...
# 3044  березвськазагальноосвтняшкола3ступенвлюбарсько...
# eie
#                                                 eoname
# 4390  Березівська загальноосвітня школа I-III ступенів  \
# 4443  Березівська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname          eoareaname
# 4390  середня загальноосвітня школа  Житомирська область    Любарський район  \
# 4443  середня загальноосвітня школа  Житомирська область  Житомирський район
#
#         eotername                                           eoparent
# 4390  с.Березівка  Відділ освіти, молоді та спорту Любарської сел...  \
# 4443  с.Березівка  Відділ освіти Житомирської районної державної ...
#
#            region       tername                                     id
# 4390  Житомирська    Любарський  березвськазагальноосвтняшкола3ступенв
# 4443  Житомирська  Житомирський  березвськазагальноосвтняшкола3ступенв
# finance
#            region                tername
# 2699  Житомирська     Житомирський район  \
# 3044  Житомирська  Любарська селищна ОТГ
#
#                                              schoolname
# 2699  Березівська загальноосвітня школа І - ІІІ ступ...  \
# 3044  Березівська загальноосвітня школа І-ІІІ ступен...
#
#                                                      id
# 2699  березвськазагальноосвтняшкола3ступенвжитомирсь...
# 3044  березвськазагальноосвтняшкола3ступенвлюбарсько...
# eie
#                                                 eoname
# 5114  Романівська загальноосвітня школа I-III ступенів  \
#
#                          eotypename            eoregname          eoareaname
# 5114  середня загальноосвітня школа  Житомирська область  Романівський район  \
#
#         eotername                                           eoparent
# 5114  с.Романівка  Відділ освіти Романівської районної державної ...  \
#
#            region       tername                                     id
# 5114  Житомирська  Романівський  романвськазагальноосвтняшкола3ступенв
# finance
#            region                tername
# 2683  Житомирська     Романівський район  \
# 2998  Житомирська  Квітнева сільська ОТГ
#
#                                              schoolname
# 2683  Романівська загальноосвітня школа І-ІІІ ступен...  \
# 2998  Романівська загальноосвітня школа І-ІІІ ступен...
#
#                                                      id
# 2683  романвськазагальноосвтняшкола3ступенвроманвськ...
# 2998  романвськазагальноосвтняшкола3ступенвменмтриль...
# eie
#                                                 eoname
# 7069  Вільшанська загальноосвітня школа I-III ступенів  \
# 9190  Вільшанська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname          eoareaname
# 7069  середня загальноосвітня школа  Житомирська область   Чуднівський район  \
# 9190  середня загальноосвітня школа  Житомирська область  Романівський район
#
#         eotername                                           eoparent
# 7069  с.Вільшанка  Відділ освіти Чуднівської районної державної а...  \
# 9190     с.Вільха  Відділ освіти Романівської районної державної ...
#
#            region       tername                                     id
# 7069  Житомирська   Чуднівський  вльшанськазагальноосвтняшкола3ступенв
# 9190  Житомирська  Романівський  вльшанськазагальноосвтняшкола3ступенв
# finance
#            region             tername
# 2677  Житомирська  Романівський район  \
#
#                                              schoolname
# 2677  Вільшанська загальноосвітня школа І-ІІІ ступен...  \
#
#                                                      id
# 2677  вльшанськазагальноосвтняшкола3ступенвроманвськ...
# eie
#                                                  eoname
# 4051  Варварівська загальноосвітня школа I-III ступенів  \
# 7129  Варварівська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname           eoareaname
# 4051  середня загальноосвітня школа  Житомирська область  Ємільчинський район  \
# 7129  середня загальноосвітня школа  Житомирська область      Олевський район
#
#          eotername                                           eoparent
# 4051  с.Варварівка  Відділ освіти Ємільчинської районної державної...  \
# 7129  с.Варварівка  Відділ освіти, молоді та спорту Олевської місь...
#
#            region        tername                                      id
# 4051  Житомирська  Ємільчинський  варварвськазагальноосвтняшкола3ступенв
# 7129  Житомирська      Олевський  варварвськазагальноосвтняшкола3ступенв
# finance
#            region              tername
# 2690  Житомирська  Ємільчинський район  \
# 2907  Житомирська  Олевська міська ОТГ
#
#                                              schoolname
# 2690  Варварівська загальноосвітня школа І-ІІІ ступе...  \
# 2907  Варварівська загальноосвітня школа І - ІІІ сту...
#
#                                                      id
# 2690  варварвськазагальноосвтняшкола3ступенвємльчинс...
# 2907  варварвськазагальноосвтняшкола3ступенволевсько...
# eie
#                                                 eoname
# 7069  Вільшанська загальноосвітня школа I-III ступенів  \
# 9190  Вільшанська загальноосвітня школа I-III ступенів
#
#                          eotypename            eoregname          eoareaname
# 7069  середня загальноосвітня школа  Житомирська область   Чуднівський район  \
# 9190  середня загальноосвітня школа  Житомирська область  Романівський район
#
#         eotername                                           eoparent
# 7069  с.Вільшанка  Відділ освіти Чуднівської районної державної а...  \
# 9190     с.Вільха  Відділ освіти Романівської районної державної ...
#
#            region       tername                                     id
# 7069  Житомирська   Чуднівський  вльшанськазагальноосвтняшкола3ступенв
# 9190  Житомирська  Романівський  вльшанськазагальноосвтняшкола3ступенв
# finance
#            region             tername
# 2677  Житомирська  Романівський район  \
#
#                                              schoolname
# 2677  Вільшанська загальноосвітня школа І-ІІІ ступен...  \
#
#                                                      id
# 2677  вльшанськазагальноосвтняшкола3ступенвроманвськ...
# eie
#                                                  eoname
# 3592  Вільховецька загальноосвітня школа I-III ступенів  \
#
#                          eotypename            eoregname           eoareaname
# 3592  середня загальноосвітня школа  Хмельницька область  Чемеровецький район  \
#
#         eotername                                           eoparent
# 3592  с.Вільхівці  Відділ освіти, культури, молоді та спорту Чеме...  \
#
#            region        tername                                      id
# 3592  Хмельницька  Чемеровецький  вльховецьказагальноосвтняшкола3ступенв
# finance
#             region                  tername
# 12045  Хмельницька      Чемеровецький район  \
# 12199  Хмельницька  Новоушицька селищна ОТГ
#
#                                               schoolname
# 12045  Вільховецька загальноосвітня школа І-ІІІ ступе...  \
# 12199  Вільховецька загальноосвітня школа І-ІІІ ступе...
#
#                                                       id
# 12045  вльховецьказагальноосвтняшкола3ступенвчемерове...
# 12199  вльховецьказагальноосвтняшкола3ступенвменфедор...

# %% [markdown]
# resolving duplicates

# %%
eie_schools_temp1.loc[4520, 'id'] = eie_schools_temp1.loc[4520, 'id']+'_'
finance_schools_temp1.loc[2196, 'id'] = finance_schools_temp1.loc[2196, 'id'][:52]+'_'+finance_schools_temp1.loc[2196, 'id'][52:]
eie_schools_temp1.loc[4051, 'id'] = 'єм'+eie_schools_temp1.loc[4051, 'id']
finance_schools_temp1.loc[2690, 'id'] = 'єм' +finance_schools_temp1.loc[2690, 'id']
eie_schools_temp1.loc[4390, 'id'] = 'люб'+eie_schools_temp1.loc[4390, 'id']
finance_schools_temp1.loc[3044, 'id'] = 'люб' +finance_schools_temp1.loc[3044, 'id']
eie_schools_temp1.loc[5114, 'id'] = 'ром'+eie_schools_temp1.loc[5114, 'id']
finance_schools_temp1.loc[2683, 'id'] = 'ром' +finance_schools_temp1.loc[2683, 'id']
eie_schools_temp1.loc[9190, 'id'] = 'ром'+eie_schools_temp1.loc[9190, 'id']
finance_schools_temp1.loc[2677, 'id'] = 'ром' +finance_schools_temp1.loc[2677, 'id']
eie_schools_temp1.loc[3592, 'id'] = 'чем'+eie_schools_temp1.loc[3592, 'id']
finance_schools_temp1.loc[12045, 'id'] = 'чем' +finance_schools_temp1.loc[12045, 'id']

# %% [markdown]
# checking after removing

# %%
for region in sorted(eie_schools_temp1.region.unique()):
    region_schools = eie_schools_temp1[eie_schools_temp1.region == region]
    region_finance = finance_schools_temp1[finance_schools_temp1.region == region]
    for id in region_schools.id:
        if (id in region_finance.id.str[:len(id)].unique()) and \
             re.findall(r'№(\d+)', region_schools.loc[region_schools.id == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id.str[:len(id)] == id, 'schoolname'].iloc[0]):
            if len(region_schools[region_schools.id == id])>1 or len(region_finance[region_finance.id.str[:len(id)] == id]) >1:
                print('eie')
                display(region_schools[region_schools.id == id])
                print('finance')
                display(region_finance[region_finance.id.str[:len(id)] == id])

# %% [markdown]
# matching

# %%
for region in sorted(eie_schools_temp1.region.unique()):
    region_schools = eie_schools_temp1[eie_schools_temp1.region == region]
    region_finance = finance_schools_temp1[finance_schools_temp1.region == region]
    for id in region_schools.id:
        if (id in region_finance.id.str[:len(id)].unique()) and \
             re.findall(r'№(\d+)', region_schools.loc[region_schools.id == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id.str[:len(id)] == id, 'schoolname'].iloc[0]):
            df = pd.concat([df, pd.DataFrame([{'eoname': region_schools.loc[region_schools.id == id, 'eoname'].iloc[0], \
                                            'schoolname': region_finance.loc[region_finance.id.str[:len(id)] == id, 'schoolname'].iloc[0],
                                            'regname': region}])], ignore_index=True)
            eie_schools_temp2 = eie_schools_temp2[~((eie_schools_temp2.region == region) & (eie_schools_temp2.id == id))]
            finance_schools_temp2 = finance_schools_temp2[~((finance_schools_temp2.region == region) & (finance_schools_temp2.id.str[:len(id)] == id))]

df.shape
# Out:
# (6579, 3)

# %%
df.tail(10)
# Out:
#                                                  eoname
# 6569                     Ліцей міжнародних відносин №51  \
# 6570  Спеціалізована школа №43 з поглибленим вивченн...
# 6571                           Спеціалізована школа №80
# 6572                               Кловський ліцей № 77
# 6573  НВК № 30 "ЕКОНАД" спеціалізована школа І ступе...
# 6574  Спеціалізована школа № 216 Оболонського району...
# 6575       Спеціалізована школа №47 імені А.С.Макаренка
# 6576  Спеціалізована школа І-ІІІ ступенів №24 ім. О....
# 6577                 Ліцей інформаційних технологій №79
# 6578  Спеціалізована школа І-ІІІ ступенів №96 ім.О.К...
#
#                                              schoolname     regname
# 6569         Ліцей міжнародних відносин №51 міста Києва  місто Київ
# 6570  спеціалізована школа №43 з поглибленим вивченн...  місто Київ
# 6571  Спеціалізована школа №80 Печерського району мі...  місто Київ
# 6572  Кловський ліцей № 77 Печерського району міста ...  місто Київ
# 6573  Навчально-виховний комплекс № 30 "ЕКОНАД" (спе...  місто Київ
# 6574  спеціалізована школа № 216 Оболонського району...  місто Київ
# 6575  Спеціалізована школа №47 імені А.С.Макаренка з...  місто Київ
# 6576  Спеціалізована школа І-ІІІ ступенів №24 ім.О.Б...  місто Київ
# 6577  Ліцей інформаційних технологій №79 Печерського...  місто Київ
# 6578  Спеціалізована школа І-ІІІ ступенів №96 ім. О....  місто Київ

# %%
print(eie_schools.shape[0]-eie_schools_temp2.shape[0])
print(finance_schools.shape[0] - finance_schools_temp2.shape[0])
print(df.shape[0])
# Out:
# 6579
# 6579
# 6579

# %% [markdown]
# matching by trimming in different direction

# %%
eie_schools_temp3 = eie_schools_temp2
finance_schools_temp3 = finance_schools_temp2

# %%
for region in sorted(eie_schools_temp2.region.unique()):
    region_schools = eie_schools_temp2[eie_schools_temp2.region == region]
    region_finance = finance_schools_temp2[finance_schools_temp2.region == region]
    for id in region_finance.id:
        if (id in region_schools.id.str[:len(id)].unique()) and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id.str[:len(id)] == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0]):
            if len(region_schools[region_schools.id.str[:len(id)] == id])>1 or len(region_finance[region_finance.id == id]) >1:
                print('data')
                display(region_schools[region_schools.id.str[:len(id)] == id])
                print('finance')
                display(region_finance[region_finance.id == id])

# %%
for region in sorted(eie_schools_temp2.region.unique()):
    region_schools = eie_schools_temp2[eie_schools_temp2.region == region]
    region_finance = finance_schools_temp2[finance_schools_temp2.region == region]
    for id in region_finance.id:
        if (id in region_schools.id.str[:len(id)].unique()) and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id.str[:len(id)] == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0]):
            df = pd.concat([df, pd.DataFrame([{'eoname':region_schools.loc[region_schools.id.str[:len(id)] == id, 'eoname'].iloc[0], \
                                            'schoolname': region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0],
                                            'regname': region}])], ignore_index=True)
            eie_schools_temp3 = eie_schools_temp3[~((eie_schools_temp3.region == region) & (eie_schools_temp3.id.str[:len(id)] == id))]
            finance_schools_temp3 = finance_schools_temp3[~((finance_schools_temp3.region == region) & (finance_schools_temp3.id == id))]
df.shape
# Out:
# (6998, 3)

# %%
print(eie_schools.shape[0]-eie_schools_temp3.shape[0])
print(finance_schools.shape[0] - finance_schools_temp3.shape[0])
print(df.shape[0])
# Out:
# 6998
# 6998
# 6998

# %%
df.tail(10)
# Out:
#                                                  eoname
# 6988  Горбівський заклад загальної середньої освіти ...  \
# 6989  Олишівська загальноосвітня школа I-III ступені...
# 6990  Спеціалізована школа №14 імені українського пр...
# 6991  Спеціалізована школа №7 імені М.Т.Рильського м...
# 6992         Середня загальноосвітня школа №12 м. Києва
# 6993  Спеціалізована школа №52 з поглибленим вивченн...
# 6994  Середня загальноосвітня школа №279 імені Петра...
# 6995  Спеціалізована школа І-ІІІ ступенів №61 з погл...
# 6996  Школа І-ІІІ ступенів №70 Шевченківського район...
# 6997  Спеціалізована школа І-ІІІ ступенів №135 з пог...
#
#                                              schoolname       regname
# 6988  Горбівський заклад загальної середньої освіти ...  Чернігівська
# 6989  Олишівська загальноосвітня школа І-ІІІ ступені...  Чернігівська
# 6990  Спеціалізована школа №14 імені українського пр...    місто Київ
# 6991       Спеціалізована школа №7 імені М.Т.Рильського    місто Київ
# 6992                  Середня загальноосвітня школа №12    місто Київ
# 6993  спеціалізована школа №52 з поглибленим вивченн...    місто Київ
# 6994  Середня загальноосвітня школа №279 імені Петра...    місто Київ
# 6995  Спеціалізована школа І-ІІІ ступенів №61 з погл...    місто Київ
# 6996    Школа І-ІІІ ступенів №70 Шевченківського району    місто Київ
# 6997  Спеціалізована школа І-ІІІ ступенів №135 з пог...    місто Київ

# %% [markdown]
# downloading dataset that has information about the status (private or public) iof schools

# %%
schools = pd.read_excel('/Users/scipyguru/Library/Mobile Documents/com~apple~CloudDocs/Documents_New/NY fairness/NeurIPS/ZNO/Заклади загальної середньої освіти.xlsx')
schools
# Out:
#                                              Повна назва  Код в ЄДЕБО
# 0                              гімназія №179 міста Києва       148440  \
# 1           гімназія №59 імені О.М. Бойченка міста Києва       148414
# 2             Еколого-природничий ліцей №116 міста Києва       148429
# 3      Заклад освіти "Приватний загальноосвітній навч...       148411
# 4                                          Ліцей «Гранд»       148412
# ...                                                  ...          ...
# 16254  комунальний заклад "Яблунівський ліцей" Черніг...       139767
# 16255  Яблунівська загальноосвітня школа I-III ступен...       144175
# 16256  Ядутинська загальноосвітня школа І-ІІІ ступені...       135163
# 16257  Янжулівська філія І-ІІ ступенів Семенівської г...       134967
# 16258  Ярославська філія І-ІІ ступенів Бобровицькогоз...       141845
#
#       ОУО підтвердив дані                                    Скорочена назва
# 0                     так                          гімназія №179 міста Києва  \
# 1                     так                                       гімназія №59
# 2                     так         Еколого-природничий ліцей №116 міста Києва
# 3                     так                                 ЗО "ПЗНЗ "МІДГАРД"
# 4                     так                                      Ліцей «Гранд»
# ...                   ...                                                ...
# 16254                 так                            КЗ "Яблунівський ліцей"
# 16255                 так                     Яблунівська ЗОШ І-ІІІ ступенів
# 16256                 так                           Ядутинська ЗОШ І-ІІІ ст.
# 16257                 так                         Янжулівська філія І-ІІ ст.
# 16258                 так  Ярославська філія І-ІІ ступенів Бобровицького ...
#
#        Статус Тип закладу Форма власності  Код КОАТУУ                Регіон
# 0      працює    гімназія      Комунальна  8036100000                  КИЇВ  \
# 1      працює    гімназія      Комунальна  8036100000                  КИЇВ
# 2      працює       ліцей      Комунальна  8036100000                  КИЇВ
# 3      працює       школа        Приватна  8036100000                  КИЇВ
# 4      працює       ліцей        Приватна  8036100000                  КИЇВ
# ...       ...         ...             ...         ...                   ...
# 16254  працює       ліцей      Комунальна  7424189701  Чернігівська область
# 16255  працює       школа      Комунальна  7424189701  Чернігівська область
# 16256  працює       школа      Комунальна  7420889601  Чернігівська область
# 16257  працює       школа      Комунальна  7424781701  Чернігівська область
# 16258  працює       школа      Комунальна  7420688401  Чернігівська область
#
#                                          Населений пункт  ...
# 0                                                   Київ  ...  \
# 1                                                   Київ  ...
# 2                                                   Київ  ...
# 3                                                   Київ  ...
# 4                                                   Київ  ...
# ...                                                  ...  ...
# 16254  с. Яблунівка, Прилуцький район, Чернігівська о...  ...
# 16255  с. Яблунівка, Прилуцький район, Чернігівська о...  ...
# 16256  с. Ядути, Борзнянський район, Чернігівська обл...  ...
# 16257  с. Янжулівка, Семенівський район, Чернігівська...  ...
# 16258  с. Ярославка, Бобровицький район, Чернігівська...  ...
#
#                           Телефон          Факс             Електронна пошта
# 0                    (044)2584242           NaN          gymn179@hotmail.com  \
# 1                    (044)5252138  (044)5252138          gymnasium59@ukr.net
# 2                    (044)2589988  (044)2589988  ecoprirodnichi116@gmail.com
# 3                  (098)888-09-99           NaN       midgard.kiev@gmail.com
# 4                    (044)2871457           NaN         school@grand.kiev.ua
# ...                           ...           ...                          ...
# 16254  (04637)65238, (04637)65282           NaN           Yablunovka@ukr.net
# 16255              (04637)6-52-42           NaN         yablunivkask@ukr.net
# 16256                (04653)27571           NaN               yaduti@ukr.net
# 16257                (046)5924644           NaN                          NaN
# 16258                (067)4223332           NaN      yaroslavka.zzso@ukr.net
#
#                          Веб-сайт                                    Керівник
# 0              http://179.kiev.ua                Директор Бойко Ірина Львівна  \
# 1      http://gymnasium59.org.ua/        Директор Антоненко Тетяна Стефанівна
# 2            http://eco116.at.ua/        Директор Авраменко Таміла Олексіївна
# 3       http://www.midgard.school            Директор Попов Олег Анатолійович
# 4          www.grandschool.com.ua        Директор Зайчук Світлана Анатоліївна
# ...                           ...                                         ...
# 16254                         NaN  Директор Шаповаленко Неоніла Олександрівна
# 16255                         NaN       Директор Колесник Анатолій Васильович
# 16256                         NaN                  Шостак Ірина Володимирівна
# 16257                         NaN   Завідувач філією Подоляк Ірина Миколаївна
# 16258                         NaN     Завідувач філією Смага Ольга Миколаївна
#
#       Опорний / Філія Сільський Гірський Інтернат Ліцензовані обсяги
# 0                  ні        ні       ні       ні             1800.0
# 1                  ні        ні       ні       ні             1800.0
# 2                  ні        ні       ні       ні                NaN
# 3                  ні        ні       ні       ні              600.0
# 4                  ні        ні       ні       ні              250.0
# ...               ...       ...      ...      ...                ...
# 16254  Опорний заклад       так       ні      так              170.0
# 16255              ні       так       ні       ні              320.0
# 16256              ні       так       ні       ні                1.0
# 16257           Філія       так       ні       ні               90.0
# 16258              ні       так       ні       ні                NaN
#
# [16259 rows x 23 columns]

# %%
schools.shape
# Out:
# (16259, 23)

# %%
schools_private = schools[schools['Форма власності'] == 'Приватна']

# %%
schools_private['id'] = schools_private ['Повна назва']
schools_private['id'] = schools_private['id'].str.replace('[\s-]', '', regex = True)
schools_private.loc[schools_private['id'].str.endswith('обл'), 'id'] = schools_private.loc[schools_private['id'].str.endswith('обл'), 'id'] + '.'
schools_private['id'] = schools_private['id'].str.replace('І', 'I')
schools_private['id'] = schools_private['id'].str.replace('I-III', '3')
schools_private['id'] = schools_private['id'].str.replace('I-II', '2')
schools_private['id'] = schools_private['id'].str.lower()

dct = {'с.':'села', 'ст.':'ступенів', 'ім.':'імені', 'iм.':'імені', 'обл.': 'області', 
       '||||':'3', '|||':'2',
       'i':'', 'і':'', 'ї':'і', 'o':'о', 'y':'у', 'p':'р', 'c':'с', 'ґ':'г', 'e':'е', 'a':'а', 'k':'к', 'x': 'х',
       "'":'', "’":'', ",":'', ".":'', "«":'', "»":'', "–":'', "-":'', 
       "_x000d_":'', '_x000D_':'', "_":'', "(":'', ")":'', "[":'', "]":'', "}":'', "{":'', 
       "нвк":'навчальновиховнийкомплекс', 'знз': 'загальноосвтнйнавчальнийзаклад', 'нн':'н', 'днз': 'дошкльнийнавчальнийзаклад'}

for symb in dct:
    schools_private['id'] = schools_private['id'].str.replace(symb, dct[symb])

schools_private['id'] = schools_private['id'].str.replace('"', '', regex = True)
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private ['Повна назва']
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace('[\s-]', '', regex = True)
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace('І', 'I')
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace('I-III', '3')
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace('I-II', '2')
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.lower()
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace(symb, dct[symb])
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1521500785.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['id'] = schools_private['id'].str.replace('"', '', regex = True)

# %%
schools_private
# Out:
#                                              Повна назва  Код в ЄДЕБО
# 3      Заклад освіти "Приватний загальноосвітній навч...       148411  \
# 4                                          Ліцей «Гранд»       148412
# 10     МІЖНАРОДНИЙ ХРИСТИЯНСЬКИЙ ПРИВАТНИЙ ЗАКЛАД ЗАГ...       176484
# 14     Навчально-виховний комплекс "Міжнародний ліцей...       144362
# 15     освітній заклад "ШКОЛА "ГРАНД-ЕКСПО" (структур...       176486
# ...                                                  ...          ...
# 15374  ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЧЕРНІ...       176567
# 15801  ПРИВАТНЕ ПІДПРИЄМСТВО "ПРИВАТНИЙ ЗАКЛАД ОСВІТИ...       148340
# 15804  ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЛІЦЕЙ...       176538
# 15805  Товариство з обмеженою відповідальністю "Прива...       176496
# 15866  ЧЕРНІГІВСЬКА ФІЛІЯ ТОВАРИСТВА З ОБМЕЖЕНОЮ ВІДП...       151640
#
#       ОУО підтвердив дані                                    Скорочена назва
# 3                     так                                 ЗО "ПЗНЗ "МІДГАРД"  \
# 4                     так                                      Ліцей «Гранд»
# 10                    так                            МХЛ м. Київ «ДІТИ ЦАРЯ»
# 14                    так                       НВК "Міжнародний ліцей МАУП"
# 15                    так                              ПП "МОК "ГРАНД-ЕКСПО"
# ...                   ...                                                ...
# 15374                 так           ТОВ "ЧЕРНІВЕЦЬКИЙ ПРИВАТНИЙ ЛІЦЕЙ "ЮНІК"
# 15801                 так                             ПП "ПЗО "МУДРАНГЕЛИКИ"
# 15804                 так                              ТОВ "ЛІЦЕЙ "РОБОСКУЛ"
# 15805                 так  ТОВ "Приватна дистанційна загальноосвітня школ...
# 15866                 так                                 ЧФ ТОВ «ШКОЛА 977»
#
#        Статус                               Тип закладу Форма власності
# 3      працює                                     школа        Приватна  \
# 4      працює                                     ліцей        Приватна
# 10     працює                                     ліцей        Приватна
# 14     працює  навчально-виховний комплекс (об'єднання)        Приватна
# 15     працює                                     школа        Приватна
# ...       ...                                       ...             ...
# 15374  працює                                     ліцей        Приватна
# 15801  працює                                     школа        Приватна
# 15804  працює                                     ліцей        Приватна
# 15805  працює                                     школа        Приватна
# 15866  працює                                  гімназія        Приватна
#
#        Код КОАТУУ                Регіон                 Населений пункт  ...
# 3      8036100000                  КИЇВ                            Київ  ...  \
# 4      8036100000                  КИЇВ                            Київ  ...
# 10     8036100000                  КИЇВ                            Київ  ...
# 14     8036100000                  КИЇВ                            Київ  ...
# 15     8036100000                  КИЇВ                            Київ  ...
# ...           ...                   ...                             ...  ...
# 15374  7310100000   Чернівецька область   Чернівці, Чернівецька область  ...
# 15801  7410136300  Чернігівська область  Чернігів, Чернігівська область  ...
# 15804  7410100000  Чернігівська область  Чернігів, Чернігівська область  ...
# 15805  7410100000  Чернігівська область  Чернігів, Чернігівська область  ...
# 15866  7410700000  Чернігівська область   Прилуки, Чернігівська область  ...
#
#       Факс           Електронна пошта                       Веб-сайт
# 3      NaN     midgard.kiev@gmail.com      http://www.midgard.school  \
# 4      NaN       school@grand.kiev.ua         www.grandschool.com.ua
# 10     NaN           kingkids@ukr.net  https://kingskids-school.com/
# 14     NaN       liceum@ilmaup.com.ua                  ilmaup.com.ua
# 15     NaN                        NaN                            NaN
# ...    ...                        ...                            ...
# 15374  NaN                        NaN                            NaN
# 15801  NaN  mudrangelschool@gmail.com        https://mudrangels.com/
# 15804  NaN     info@roboschool.org.ua                            NaN
# 15805  NaN   manager.redfox@gmail.com                            NaN
# 15866  NaN          977info@gmail.com                     977.com.ua
#
#                                              Керівник Опорний / Філія
# 3                    Директор Попов Олег Анатолійович              ні  \
# 4                Директор Зайчук Світлана Анатоліївна              ні
# 10                Директор Богорад Алла Олександрівна              ні
# 14                    Директор Зеленська Зоя Петрівна              ні
# 15            Директор Веприцька Тетяна Володимирівна              ні
# ...                                               ...             ...
# 15374              Директор Куницька Ірина Михайлівна              ні
# 15801               Директор Лавріненко Неля Петрівна              ні
# 15804               Директор Лимар Сергій Миколайович              ні
# 15805             Директор Василенко Неля Анатоліївна              ні
# 15866  Завідувач філією Пономаренко Валерій Борисович           Філія
#
#       Сільський Гірський Інтернат Ліцензовані обсяги
# 3            ні       ні       ні              600.0  \
# 4            ні       ні       ні              250.0
# 10           ні       ні       ні                NaN
# 14           ні       ні       ні                NaN
# 15           ні       ні       ні                NaN
# ...         ...      ...      ...                ...
# 15374        ні       ні       ні                NaN
# 15801        ні       ні       ні                NaN
# 15804        ні       ні       ні                NaN
# 15805        ні       ні       ні              300.0
# 15866        ні       ні       ні                1.0
#
#                                                       id
# 3      закладосвтиприватнийзагальноосвтнйнавчальнийза...
# 4                                              лцейгранд
# 10     мжнароднийхристиянськийприватнийзакладзагально...
# 14     навчальновиховнийкомплексмжнароднийлцеймжрегон...
# 15     освтнйзакладшколаграндекспоструктурнийпдроздлп...
# ...                                                  ...
# 15374  товариствозобмеженоювдповдальнстючернвецькийпр...
# 15801  приватнепдприємствоприватнийзакладосвтимудранг...
# 15804  товариствозобмеженоювдповдальнстюлцейробоскулм...
# 15805  товариствозобмеженоювдповдальнстюприватнадиста...
# 15866  чернгвськафлятовариствазобмеженоювдповдальнстю...
#
# [429 rows x 24 columns]

# %%
set(schools_private['Регіон'])-set(eie_schools.region)
# Out:
# {'Івано-Франківська область',
#  'Волинська область',
#  'Вінницька область',
#  'Дніпропетровська область',
#  'Донецька область',
#  'Житомирська область',
#  'Закарпатська область',
#  'Запорізька область',
#  'КИЇВ',
#  'Київська область',
#  'Кіровоградська область',
#  'Луганська область',
#  'Львівська область',
#  'Миколаївська область',
#  'Одеська область',
#  'Полтавська область',
#  'Рівненська область',
#  'Сумська область',
#  'Харківська область',
#  'Херсонська область',
#  'Хмельницька область',
#  'Черкаська область',
#  'Чернівецька область',
#  'Чернігівська область'}

# %%
schools_private['region'] = schools_private['Регіон'].str.split().str[0]
schools_private['region'] = schools_private['region'].str.replace('КИЇВ', 'місто Київ')
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1340364044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['region'] = schools_private['Регіон'].str.split().str[0]
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_69176/1340364044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_private['region'] = schools_private['region'].str.replace('КИЇВ', 'місто Київ')

# %%
set(schools_private.region)-set(eie_schools.region)
# Out:
# set()

# %%
eie_schools_temp4 = eie_schools_temp3

# %% [markdown]
# removing from our dataset for matching all private schools

# %%
count = 0
for region in sorted(eie_schools_temp3.region.unique()):
    region_schools = eie_schools_temp3[eie_schools_temp3.region == region]
    for id in region_schools.id:
        if id in schools_private.id.str[:len(id)].unique():
            count +=1
            eie_schools_temp4 = eie_schools_temp4[eie_schools_temp4.id != id]

df.shape
# Out:
# (6998, 3)

# %%
count
# Out:
# 26

# %%
print(eie_schools.shape[0]-eie_schools_temp4.shape[0])
print(finance_schools.shape[0] - finance_schools_temp3.shape[0]+count)
print(df.shape[0]+count)
# Out:
# 7024
# 7024
# 7024

# %%
eie_schools_temp5 = eie_schools_temp4
finance_schools_temp5 = finance_schools_temp3

# %% [markdown]
# matching by contains

# %%
for region in sorted(eie_schools_temp4.region.unique()):
    region_schools = eie_schools_temp4[eie_schools_temp4.region == region]
    region_finance = finance_schools_temp3[finance_schools_temp3.region == region]
    for id in region_schools.id:
        matching_long_values = region_finance[region_finance.id.str.contains(id)]
        if not matching_long_values.empty and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id.str.contains(id), 'schoolname'].iloc[0]):
            
            if len(matching_long_values)>1 or len(region_schools[region_schools.id == id])>1:
                print('data')
                display(region_schools[region_schools.id == id])
                print('finance')
                display(matching_long_values)

# %%
for region in sorted(eie_schools_temp4.region.unique()):
    region_schools = eie_schools_temp4[eie_schools_temp4.region == region]
    region_finance = finance_schools_temp3[finance_schools_temp3.region == region]
    for id in region_schools.id:
        matching_long_values = region_finance[region_finance.id.str.contains(id)]
        if not matching_long_values.empty and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id == id, 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id.str.contains(id), 'schoolname'].iloc[0]):

            df = pd.concat([df, pd.DataFrame([{'eoname': region_schools.loc[region_schools.id == id, 'eoname'].iloc[0], \
                                            'schoolname': region_finance.loc[region_finance['id'].str.contains(id), 'schoolname'].iloc[0],
                                            'regname':region}])], ignore_index=True)
            eie_schools_temp5 = eie_schools_temp5[~((eie_schools_temp5.region == region) & (eie_schools_temp5.id == id))]
            finance_schools_temp5 = finance_schools_temp5[~((finance_schools_temp5.region == region) & (finance_schools_temp5.id.str.contains(id)))]

df.shape
# Out:
# (7048, 3)

# %%
df.tail()
# Out:
#                                                  eoname
# 7043  Гімназія Корсунь-Шевченківської районної ради ...  \
# 7044  Орловецька загальноосвітня школа І-ІІІ ступені...
# 7045  Недобоївський заклад загальної середньої освіт...
# 7046          Ліцей №303 суспільно-природничого профілю
# 7047              Школа І-ІІІ ступенів №236 міста Києва
#
#                                              schoolname      regname
# 7043  Корсунь-Шевченківська гімназія Корсунь-Шевченк...    Черкаська
# 7044  _x000D_\nОрловецька загальноосвітня школа І - ...    Черкаська
# 7045  Державна організація (установа, заклад) Недобо...  Чернівецька
# 7046  місто Київ, ліцей №303 суспільно-природничого ...   місто Київ
# 7047  Загальноосвітня школа І-ІІІ ступенів №236 міст...   місто Київ

# %%
print(eie_schools.shape[0]-eie_schools_temp5.shape[0])
print(finance_schools.shape[0] - finance_schools_temp5.shape[0]+count)
print(df.shape[0]+count)
# Out:
# 7074
# 7074
# 7074

# %%
eie_schools_temp6 = eie_schools_temp5
finance_schools_temp6 = finance_schools_temp5

# %%
for region in sorted(eie_schools_temp5.region.unique()):
    region_schools = eie_schools_temp5[eie_schools_temp5.region == region]
    region_finance = finance_schools_temp5[finance_schools_temp5.region == region]
    for id in region_finance.id:
        matching_long_values = region_schools[region_schools.id.str.contains(id)]
        if not matching_long_values.empty and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id.str.contains(id), 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0]):
            
            if len(matching_long_values)>1:
                print(id)
                print('data')
                display(matching_long_values)
                print('finance')
                display(region_finance[region_finance.id == id])

# %%
for region in sorted(eie_schools_temp5.region.unique()):
    region_schools = eie_schools_temp5[eie_schools_temp5.region == region]
    region_finance = finance_schools_temp5[finance_schools_temp5.region == region]
    for id in region_finance.id:
        matching_long_values = region_schools[region_schools.id.str.contains(id)]
        if not matching_long_values.empty and \
            re.findall(r'№(\d+)', region_schools.loc[region_schools.id.str.contains(id), 'eoname'].iloc[0]) == \
                re.findall(r'№(\d+)', region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0]):
            
            df = pd.concat([df, pd.DataFrame([{'eoname': region_schools.loc[region_schools.id.str.contains(id), 'eoname'].iloc[0], \
                                            'schoolname': region_finance.loc[region_finance.id == id, 'schoolname'].iloc[0],
                                            'regname':region}])], ignore_index=True)
            eie_schools_temp6 = eie_schools_temp6[~((eie_schools_temp6.region == region) & (eie_schools_temp6.id.str.contains(id)))]
            finance_schools_temp6 = finance_schools_temp6[~((finance_schools_temp6.region == region) & (finance_schools_temp6.id == id))]


df.shape
# Out:
# (7061, 3)

# %%
df.tail()
# Out:
#                                                  eoname
# 7056  Комунальний заклад навчально-виховний комплекс...  \
# 7057  ОНЗ Кременчуківський ліцей Красилівського райо...
# 7058  Чернівецька загальноосвітня школа І-ІІІ ступен...
# 7059  Комунальний заклад "Навчально-виховний комплек...
# 7060  Політехнічний ліцей Національного технічного у...
#
#                                              schoolname      regname
# 7056  Навчально-виховний комплекс "Оженинська загаль...   Рівненська
# 7057  Кременчуківський ліцей Красилівського району Х...  Хмельницька
# 7058  Загальноосвітня школа І-ІІІ ступенів №1 Чернів...  Чернівецька
# 7059  Навчально-виховний комплекс " Школа І ступеня ...   місто Київ
# 7060  Технічний ліцей Національного технічного уніве...   місто Київ

# %%
print(eie_schools.shape[0]-eie_schools_temp6.shape[0])
print(finance_schools.shape[0] - finance_schools_temp6.shape[0]+count)
print(df.shape[0]+count)
# Out:
# 7087
# 7087
# 7087

# %%
eie_schools_temp6.to_csv('zno_schools_unmatched_2019.csv', index=False)

# %%
finance_schools_temp6.to_csv('finance_schools_unmatched_2019.csv', index=False)

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df[df[['eoname','regname']].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [eoname, schoolname, regname]
# Index: []

# %%
df = df.drop([2546, 6136, 6251, 6255, 6256, 6273])

# %%
df.to_csv('finance_schools_matched_2019.csv', index=False)

# %%
df.shape
# Out:
# (7055, 3)

# %%
print('need to match', eie_schools.shape[0]-df.shape[0], 'schools')
# Out:
# need to match 2519 schools

# %%
print('matched', round(df.shape[0]/eie_schools.shape[0]*100), '% of schools')
# Out:
# matched 74 % of schools
