# %%
import numpy as np
import pandas as pd

# %%
# load datasets
datasets = {}
years = range(2016, 2023)
for year in years:
    print(f"EIE {year} Loading...")
    if int(year) >= 2019:
        file_name = f'Odata{year}File.csv'
    else:
        file_name = f'OpenData{year}.csv'
    try:           
        dataset = pd.read_csv(f"../../zno/{year}/{file_name}", sep=";", encoding='utf-8')
    except:
        dataset = pd.read_csv(f"../../zno/{year}/{file_name}", sep=";", encoding='Windows 1251')
    datasets.update({year:dataset})
    print("success")
# Out:
# EIE 2016 Loading...
# success
# EIE 2017 Loading...
# success
# EIE 2018 Loading...
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_85301/3686568105.py:11: DtypeWarning: Columns (119) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(f"../../zno/{year}/{file_name}", sep=";", encoding='utf-8')
# success
# EIE 2019 Loading...
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_85301/3686568105.py:13: DtypeWarning: Columns (100,116,117,118,120,122,123,124,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(f"../../zno/{year}/{file_name}", sep=";", encoding='Windows 1251')
# success
# EIE 2020 Loading...
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_85301/3686568105.py:13: DtypeWarning: Columns (96,97,98,100,102,103,104,105,116,117,118,120,122,123,124,125) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
for year, dataset in datasets.items():
    #lowercase all columns and add year as attribute
    dataset.columns = [col.lower() for col in dataset.columns]

# %%
for year, dataset in datasets.items():
    print([col for col in dataset.columns if col.startswith('eo')])
# Out:
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']
# ['eoname', 'eotypename', 'eoregname', 'eoareaname', 'eotername', 'eoparent']

# %%
schools_edrpou = pd.DataFrame(columns=['eoname', 'eoregname', 'eoareaname', 'eotername'])

# %%
for year, dataset in datasets.items():
    schools_edrpou = pd.concat([schools_edrpou, dataset.loc[:, ['eoname', 'eoregname', 'eoareaname', 'eotername']]], ignore_index=True)

schools_edrpou
# Out:
#                                                     eoname
# 0        Терпіннівський колегіум "Джерело" Мелітопольсь...  \
# 1        Красилівська загальноосвітня школа I-III ступе...
# 2                                                      NaN
# 3        Чернівецька спеціалізована школа І-ІІІ ступені...
# 4                                                      NaN
# ...                                                    ...
# 2201113  Заболотцівський ліцей Литовезької сільської ра...
# 2201114  Заболотцівський ліцей Литовезької сільської ра...
# 2201115  Заболотцівський ліцей Литовезької сільської ра...
# 2201116  Заболотцівський ліцей Литовезької сільської ра...
# 2201117  Павлівська загальноосвітня школа I-III ступені...
#
#                    eoregname             eoareaname
# 0         Запорізька область  Мелітопольський район  \
# 1        Хмельницька область    Красилівський район
# 2                        NaN                    NaN
# ...

# %%
schools_edrpou.drop_duplicates(inplace=True)
# when paricipant graduated in the previous years the corresponding information about school
# (everything with 'eo') is NaN
#we drop these rows
schools_edrpou.dropna(how = 'all', inplace=True)
schools_edrpou.reset_index(drop=True, inplace=True)
schools_edrpou
# Out:
#                                                   eoname
# 0      Терпіннівський колегіум "Джерело" Мелітопольсь...  \
# 1      Красилівська загальноосвітня школа I-III ступе...
# 2      Чернівецька спеціалізована школа І-ІІІ ступені...
# 3      Загальноосвітня школа I-III ступенів № 6 Дружк...
# 4      Тернопільська спеціалізована школа І-ІІІ ступе...
# ...                                                  ...
# 34380  Гульський ліцей Стриївської сільської ради Нов...
# 34381  Киківський ліцей Стриївської сільської ради Но...
# 34382  Литовезький ліцей імені Володимира Якобчука Во...
# 34383  Заболотцівський ліцей Литовезької сільської ра...
# 34384  Павлівська загальноосвітня школа I-III ступені...
#
#                    eoregname                 eoareaname
# 0         Запорізька область      Мелітопольський район  \
# 1        Хмельницька область        Красилівський район
# 2        Чернівецька область                 м.Чернівці
# ...

# %%
locations = pd.read_csv('./location_data/locations.csv', encoding='utf-8', dtype=str)
locations
# Out:
#                         regname                areaname
# 0            Запорізька область   Мелітопольський район  \
# 1           Хмельницька область     Красилівський район
# 2      Дніпропетровська область  Петропавлівський район
# 3           Чернівецька область              м.Чернівці
# 4          Миколаївська область      Врадіївський район
# ...                         ...                     ...
# 28878               Інші країни             м.Гронінген
# 28879               Інші країни            м.Люксембург
# 28880               Інші країни               м.Марібор
# 28881               Інші країни            м.Сакраменто
# 28882               Інші країни              м.Едмонтон
#
#                           tername KOATUU_2020         KATOTTG_2023
# 0                      с.Терпіння  2323085101  UA23080270010078454
# 1                      м.Красилів  6822710100  UA68040210010032567
# 2                     с.Дмитрівка  1223881501  UA12140170040016918
# ...

# %%
schools_edrpou = schools_edrpou.merge(locations[['KOATUU_2020']], left_on=[schools_edrpou['eoregname'],schools_edrpou['eoareaname'], schools_edrpou['eotername']], right_on=[locations['regname'],locations['areaname'], locations['tername']], how='left')
schools_edrpou = schools_edrpou.drop(columns = ['key_0', 'key_1', 'key_2'], axis=1)
schools_edrpou.head()
# Out:
#                                               eoname              eoregname
# 0  Терпіннівський колегіум "Джерело" Мелітопольсь...     Запорізька область  \
# 1  Красилівська загальноосвітня школа I-III ступе...    Хмельницька область
# 2  Чернівецька спеціалізована школа І-ІІІ ступені...    Чернівецька область
# 3  Загальноосвітня школа I-III ступенів № 6 Дружк...       Донецька область
# 4  Тернопільська спеціалізована школа І-ІІІ ступе...  Тернопільська область
#
#               eoareaname                   eotername KOATUU_2020
# 0  Мелітопольський район                  с.Терпіння  2323085101
# 1    Красилівський район                  м.Красилів  6822710100
# 2             м.Чернівці  Шевченківський район міста  7310100000
# 3       Донецька область                 м.Дружківка  1411700000
# 4  Тернопільська область                 м.Тернопіль  6110100000

# %%
schools_edrpou_id= schools_edrpou[['eoname', 'KOATUU_2020']]
schools_edrpou_id.drop_duplicates(inplace=True)
schools_edrpou_id.reset_index(drop=True, inplace=True)
schools_edrpou_id
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_85301/3377070480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_edrpou_id.drop_duplicates(inplace=True)
#                                                   eoname KOATUU_2020
# 0      Терпіннівський колегіум "Джерело" Мелітопольсь...  2323085101
# 1      Красилівська загальноосвітня школа I-III ступе...  6822710100
# 2      Чернівецька спеціалізована школа І-ІІІ ступені...  7310100000
# 3      Загальноосвітня школа I-III ступенів № 6 Дружк...  1411700000
# 4      Тернопільська спеціалізована школа І-ІІІ ступе...  6110100000
# ...                                                  ...         ...
# 27506  Гульський ліцей Стриївської сільської ради Нов...  1824081001
# ...

# %%
schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['eoname']

abbr = {'КЗ ':'Комунальний заклад ', 'ОНЗ ':'Опорний навчальний заклад ', 'ОЗЗСО ':'Опорний заклад загальної середньої освіти ',
        'ЗЗСО ':'Заклад загальної середньої освіти ', 'ООЗ ':'Опорний освітній заклад ', 'ЗСО ':'Загальної середньої освіти ', 
        'НВК ':'Навчально-виховний комплекс ', 'ЗОШ ':'Загальнооосвітня школа ', 'СЗШ ':'Середня загальноосвітня школа ', 'ТОВ ': 'Товариство з обмеженою відповідальністю '}

for ab in abbr:
    schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace(ab, abbr[ab])

schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace('[\s]', '', regex = True)
schools_edrpou_id.loc[schools_edrpou_id['id'].str.endswith('обл'), 'id'] = schools_edrpou_id.loc[schools_edrpou_id['id'].str.endswith('обл'), 'id'] + '.'
schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace('І', 'I')
schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace('I-III', '3')
schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace('I-II', '2')
schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.lower()

dct = {'с.':'села', 'ст.':'ступенів', 'ім.':'імені', 'iм.':'імені', 'обл.': 'області', 
       '||||':'3', '|||':'2',
       'i':'', 'і':'', 'ї':'', 'o':'о', 'y':'у', 'p':'р', 'c':'с', 'ґ':'г', 'e':'е', 'a':'а', 'k':'к', 'x': 'х', 
       "'":'', "’":'', ",":'', ".":'', "«":'', "»":'', "–":'', "-":'', "*":"",
       "_x000d_":'', '_x000D_':'', "_":'', "(":'', ")":'', "[":'', "]":'', "}":'', "{":'', 
       "нвк":'навчальновиховнийкомплекс', 'знз': 'загальноосвтнйнавчальнийзаклад', 'зош': 'загальноосвтняшкола', 
       'сзш':'середнязагальноосвтняшкола', 'нн':'н'}

for symb in dct:
    schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace(symb, dct[symb])

schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['id'].str.replace('"', '', regex = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-769597fdd9af> in <module>
# ----> 1 schools_edrpou_id.loc[:,'id'] = schools_edrpou_id['eoname']
#       2
#       3 abbr = {'КЗ ':'Комунальний заклад ', 'ОНЗ ':'Опорний навчальний заклад ', 'ОЗЗСО ':'Опорний заклад загальної середньої освіти ',
#       4         'ЗЗСО ':'Заклад загальної середньої освіти ', 'ООЗ ':'Опорний освітній заклад ', 'ЗСО ':'Загальної середньої освіти ',
#       5         'НВК ':'Навчально-виховний комплекс ', 'ЗОШ ':'Загальнооосвітня школа ', 'СЗШ ':'Середня загальноосвітня школа ', 'ТОВ ': 'Товариство з обмеженою відповідальністю '}
#
# NameError: name 'schools_edrpou_id' is not defined

# %%
schools_edrpou_id
# Out:
#                                                   eoname KOATUU_2020
# 0      Терпіннівський колегіум "Джерело" Мелітопольсь...  2323085101  \
# 1      Красилівська загальноосвітня школа I-III ступе...  6822710100
# 2      Чернівецька спеціалізована школа І-ІІІ ступені...  7310100000
# 3      Загальноосвітня школа I-III ступенів № 6 Дружк...  1411700000
# 4      Тернопільська спеціалізована школа І-ІІІ ступе...  6110100000
# ...                                                  ...         ...
# 27506  Гульський ліцей Стриївської сільської ради Нов...  1824081001
# 27507  Киківський ліцей Стриївської сільської ради Но...  1824081801
# 27508  Литовезький ліцей імені Володимира Якобчука Во...  0721182401
# 27509  Заболотцівський ліцей Литовезької сільської ра...  0721182403
# 27510  Павлівська загальноосвітня школа I-III ступені...  6525483001
#
#                                                       id
# 0      терпнвськийколегумджереломелтопольськорайонора...
# ...

# %%
schools_data = pd.read_excel('./school_data/Schools_02.08.2023 16-56.xlsx', dtype = str)
schools_data
# Out:
#                                              Повна назва Код в ЄДЕБО
# 0      «ПРИВАТНИЙ ЗАКЛАД ОСВІТИ «КМДШ» №2 М. КИЇВ» (В...      150646  \
# 1                             Гімназія № 236 міста Києва      148438
# 2                              Гімназія № 87 міста Києва      148421
# 3                              Гімназія №150 міста Києва      148431
# 4                              гімназія №179 міста Києва      148440
# ...                                                  ...         ...
# 17330  Яблунівський навчально-виховний комплекс "Зага...      144723
# 17331  Ягіднянська філія опорного закладу "Количівськ...      145351
# 17332  Ядутинська загальноосвітня школа І-ІІІ ступені...      135163
# 17333  Янжулівська філія І-ІІ ступенів Семенівської г...      134967
# 17334  Ярославська філія І-ІІ ступенів Бобровицькогоз...      141845
#
#       ОУО підтвердив дані                                    Скорочена назва
# ...

# %%
schools_data_id = schools_data

# %%
schools_data_id['id'] = schools_data_id['Повна назва']

abbr = {'КЗ ':'Комунальний заклад ', 'ОНЗ ':'Опорний навчальний заклад ', 'ОЗЗСО ':'Опорний заклад загальної середньої освіти ',
        'ЗЗСО ':'Заклад загальної середньої освіти ', 'ООЗ ':'Опорний освітній заклад ', 'ЗСО ':'Загальної середньої освіти ', 
        'НВК ':'Навчально-виховний комплекс ', 'ЗОШ ':'Загальнооосвітня школа ', 'СЗШ ':'Середня загальноосвітня школа ', 'ТОВ ': 'Товариство з обмеженою відповідальністю '}

for ab in abbr:
    schools_data_id['id'] = schools_data_id['id'].str.replace(ab, abbr[ab])

schools_data_id['id'] = schools_data_id['id'].str.replace('[\s]', '', regex = True)
schools_data_id.loc[schools_data_id['id'].str.endswith('обл'), 'id'] = schools_data_id.loc[schools_edrpou_id['id'].str.endswith('обл'), 'id'] + '.'
schools_data_id['id'] = schools_data_id['id'].str.replace('І', 'I')
schools_data_id['id'] = schools_data_id['id'].str.replace('I-III', '3')
schools_data_id['id'] = schools_data_id['id'].str.replace('I-II', '2')
schools_data_id['id'] = schools_data_id['id'].str.lower()

dct = {'с.':'села', 'ст.':'ступенів', 'ім.':'імені', 'iм.':'імені', 'обл.': 'області', 
       '||||':'3', '|||':'2',
       'i':'', 'і':'', 'ї':'', 'o':'о', 'y':'у', 'p':'р', 'c':'с', 'ґ':'г', 'e':'е', 'a':'а', 'k':'к', 'x': 'х', 
       "'":'', "’":'', ",":'', ".":'', "«":'', "»":'', "–":'', "-":'', "*":"",
       "_x000d_":'', '_x000D_':'', "_":'', "(":'', ")":'', "[":'', "]":'', "}":'', "{":'', 
       "нвк":'навчальновиховнийкомплекс', 'знз': 'загальноосвтнйнавчальнийзаклад', 'зош': 'загальноосвтняшкола', 
       'сзш':'середнязагальноосвтняшкола', 'нн':'н'}

for symb in dct:
    schools_data_id['id'] = schools_data_id['id'].str.replace(symb, dct[symb])

schools_data_id['id'] = schools_data_id['id'].str.replace('"', '', regex = True)

# %%
schools_data_id
# Out:
#                                              Повна назва Код в ЄДЕБО
# 0      «ПРИВАТНИЙ ЗАКЛАД ОСВІТИ «КМДШ» №2 М. КИЇВ» (В...      150646  \
# 1                             Гімназія № 236 міста Києва      148438
# 2                              Гімназія № 87 міста Києва      148421
# 3                              Гімназія №150 міста Києва      148431
# 4                              гімназія №179 міста Києва      148440
# ...                                                  ...         ...
# 17330  Яблунівський навчально-виховний комплекс "Зага...      144723
# 17331  Ягіднянська філія опорного закладу "Количівськ...      145351
# 17332  Ядутинська загальноосвітня школа І-ІІІ ступені...      135163
# 17333  Янжулівська філія І-ІІ ступенів Семенівської г...      134967
# 17334  Ярославська філія І-ІІ ступенів Бобровицькогоз...      141845
#
#       ОУО підтвердив дані                                    Скорочена назва
# ...

# %%
schools_ed = schools_edrpou_id.merge(schools_data_id[['Код ЄДРПОУ']], left_on=[schools_edrpou_id['id'],schools_edrpou_id['KOATUU_2020']], right_on=[schools_data_id['id'],schools_data_id['Код КОАТУУ']], how='left')
schools_ed = schools_ed.drop(columns = ['key_0', 'key_1'], axis=1)
schools_ed.head()
# Out:
#                                               eoname KOATUU_2020
# 0  Терпіннівський колегіум "Джерело" Мелітопольсь...  2323085101  \
# 1  Красилівська загальноосвітня школа I-III ступе...  6822710100
# 2  Чернівецька спеціалізована школа І-ІІІ ступені...  7310100000
# 3  Загальноосвітня школа I-III ступенів № 6 Дружк...  1411700000
# 4  Тернопільська спеціалізована школа І-ІІІ ступе...  6110100000
#
#                                                   id Код ЄДРПОУ
# 0  терпнвськийколегумджереломелтопольськорайонора...        NaN
# 1  красилвськазагальноосвтняшкола3ступенв№3красил...        NaN
# 2  чернвецькаспецалзованашкола3ступенвфзикоматема...        NaN
# 3  загальноосвтняшкола3ступенв№6дружквськомськора...   25705061
# 4  тернопльськаспецалзованашкола3ступенв№3зпоглиб...   14040173

# %%
schools_ed[schools_ed['Код ЄДРПОУ'].isna()]
# Out:
#                                                   eoname KOATUU_2020
# 0      Терпіннівський колегіум "Джерело" Мелітопольсь...  2323085101  \
# 1      Красилівська загальноосвітня школа I-III ступе...  6822710100
# 2      Чернівецька спеціалізована школа І-ІІІ ступені...  7310100000
# 5      Тарасівський навчально-виховний комплекс "Зага...  3523486901
# 6      Одеська загальноосвітня школа № 14 I-III ступе...  5110137600
# ...                                                  ...         ...
# 27498  Зорянський заклад загальної середньої освіти і...  1422482708
# 27505  Стратіївський заклад загальної середньої освіт...  0525085301
# 27508  Бібрський опорний ліцей імені Уляни Кравченко ...  4623310300
# 27514  Литовезький ліцей імені Володимира Якобчука Во...  0721182401
# 27515  Заболотцівський ліцей Литовезької сільської ра...  0721182403
#
#                                                       id Код ЄДРПОУ
# 0      терпнвськийколегумджереломелтопольськорайонора...        NaN
# ...

# %%
schools_ed[schools_ed['Код ЄДРПОУ'].notna()]
# Out:
#                                                   eoname KOATUU_2020
# 3      Загальноосвітня школа I-III ступенів № 6 Дружк...  1411700000  \
# 4      Тернопільська спеціалізована школа І-ІІІ ступе...  6110100000
# 38     Слов'янський педагогічний ліцей Слов'янської м...  1414100000
# 46     Комунальний заклад «Харківська загальноосвітня...  6310138500
# 47     Черкаська загальноосвітня школа І-ІІІ ступенів...  7110136400
# ...                                                  ...         ...
# 27510  Свірзький ліцей Бібрської міської ради Львівсь...  4623386401
# 27511  Суслівський ліцей Стриївської сільської ради Н...  1824085601
# 27512  Гульський ліцей Стриївської сільської ради Нов...  1824081001
# 27513  Киківський ліцей Стриївської сільської ради Но...  1824081801
# 27516  Павлівська загальноосвітня школа I-III ступені...  6525483001
#
#                                                       id Код ЄДРПОУ
# 3      загальноосвтняшкола3ступенв№6дружквськомськора...   25705061
# ...

# %%
unmatched = schools_ed[schools_ed['Код ЄДРПОУ'].isna()].sort_values(by=['KOATUU_2020', 'eoname'])

# %%
unmatched.to_csv('unmatched.csv', index=False)

# %%
#!pip install -U duckpy
from duckpy import Client
from tqdm import tqdm
import time
tqdm.pandas()

def search_opendatabot(school_name, max_retry=20):
    """
    Search for school in opendatabot.ua
    """
    client = Client()
    opendatabot_url = ''
    retry = 0
    while not opendatabot_url and retry < max_retry:
        try:
            results = client.search(school_name.replace('"','').replace("'","")+ ' ЄДРПОУ', limit=20)
        except:
            time.sleep(20)
            continue
        for site in results:
            if site['url'].startswith('https://opendatabot.ua/c/'):
                opendatabot_url = site['url']
                break
        retry += 1
    return {'eoname': school_name, "url": opendatabot_url}

search_opendatabot("Комаровецький заклад загальної середньої освіти І-ІІ ступенів - заклад дошкільної освіти Барської міської ради")
# Out:
# {'eoname': 'Комаровецький заклад загальної середньої освіти І-ІІ ступенів - заклад дошкільної освіти Барської міської ради',
#  'url': 'https://opendatabot.ua/c/26229527'}

# %%
opendatabot_links = []
for eoname in tqdm(unmatched['eoname']):
    opendatabot_links.append(search_opendatabot(eoname))
# Out:
# 100%|██████████| 22121/22121 [22:09:37<00:00,  3.61s/it]

# %%
opendatabot_df = pd.DataFrame(opendatabot_links)
# TODO: join with unmatched table

# %%
# # Works faster, but they will block your IP if you send too many requests
# from concurrent.futures.thread import ThreadPoolExecutor
# import concurrent

# opendatabot_links = []



# with ThreadPoolExecutor() as executor:
#     futures = []
#     print("Loading executor")
#     for eoname in tqdm(unmatched['eoname']):
#         future = executor.submit(search_opendatabot, eoname)
#         futures.append(future)
    
#     print("Collecting results from executor")
#     with tqdm(total=len(unmatched['eoname'])) as pbar:
#         for future in concurrent.futures.as_completed(futures):
#             result = future.result()
#             opendatabot_links.append(result)
#             pbar.update(1)

# %%
opendatabot_df
# Out:
#                                                   eoname
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  \
# 1                 Вище професійне училище №11 м. Вінниці
# 2      Вище художнє професійно-технічне училище №5 м....
# 3      Відокремлений структурний підрозділ "Вінницьки...
# 4      Відокремлений структурний підрозділ "Вінницьки...
# ...                                                  ...
# 22116  Школа №25 І-ІІІ ступенів Шевченківського район...
# 22117  Школа №27 І-ІІІ ступенів Шевченківського район...
# 22118  Школа №70 І-ІІІ ступенів Шевченківського район...
# 22119  Школа №95 І-ІІІ ступенів Шевченківського район...
# 22120  Лучицький навчально-виховний комплекс "Загальн...
#
#                                      url
# 0      https://opendatabot.ua/c/00419667
# 1      https://opendatabot.ua/c/03065891
# 2      https://opendatabot.ua/c/02539890
# 3      https://opendatabot.ua/c/35725833
# 4      https://opendatabot.ua/c/38417484
# ...

# %%
opendatabot_df[opendatabot_df.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
# Out:
#                                                   eoname
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  \
# 1                 Вище професійне училище №11 м. Вінниці
# 2      Вище художнє професійно-технічне училище №5 м....
# 3      Відокремлений структурний підрозділ "Вінницьки...
# 4      Відокремлений структурний підрозділ "Вінницьки...
# ...                                                  ...
# 22104              ТОВ "Політико-правовий коледж "АЛСКО"
# 22117  Школа №27 І-ІІІ ступенів Шевченківського район...
# 22118  Школа №70 І-ІІІ ступенів Шевченківського район...
# 22119  Школа №95 І-ІІІ ступенів Шевченківського район...
# 22120  Лучицький навчально-виховний комплекс "Загальн...
#
#                                      url
# 0      https://opendatabot.ua/c/00419667
# 1      https://opendatabot.ua/c/03065891
# 2      https://opendatabot.ua/c/02539890
# 3      https://opendatabot.ua/c/35725833
# 4      https://opendatabot.ua/c/38417484
# ...

# %%
unmatched_link = unmatched.merge(opendatabot_df[['url']], left_on=[unmatched['eoname']], right_on=[opendatabot_df['eoname']], how='left')
unmatched_link = unmatched_link.drop(columns = ['key_0'], axis=1)
unmatched_link.head()
# Out:
#                                               eoname KOATUU_2020
# 0  ВСП "Технологічно-промисловий фаховий коледж В...  0510100000  \
# 1             Вище професійне училище №11 м. Вінниці  0510100000
# 2  Вище художнє професійно-технічне училище №5 м....  0510100000
# 3  Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4  Відокремлений структурний підрозділ "Вінницьки...  0510100000
#
#                                                   id Код ЄДРПОУ
# 0  всптехнологчнопромисловийфаховийколеджвницьког...        NaN  \
# 1                       вищепрофесйнеучилище№11мвниц        NaN
# 2         вищехудожнєпрофесйнотехнчнеучилище№5мвниця        NaN
# 3  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
# 4  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
#
#                                  url
# 0  https://opendatabot.ua/c/00419667
# 1  https://opendatabot.ua/c/03065891
# 2  https://opendatabot.ua/c/02539890
# ...

# %%
unmatched_link.to_csv('unmatched_link.csv', index=False)

# %%
unmatched_new = unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
unmatched_new
# Out:
#                                                   eoname KOATUU_2020
# 5      Відокремлений структурний підрозділ «Вінницьки...  0510100000  \
# 6      Відокремлений структурний підрозділ Вінницький...  0510100000
# 7      Відокремлений структурний підрозділ Закладу ви...  0510100000
# 8      Вінницька Установа виконання покарань Управлін...  0510100000
# 9      Вінницька виправна колонія Управління Державно...  0510100000
# ...                                                  ...         ...
# 22434  Школа №163 І-ІІІ ступенів імені М.Кирпоноса Ше...  8039100000
# 22435  Школа №169 І-ІІІ ступенів Шевченківського райо...  8039100000
# 22436  Школа №175 І-ІІІ ступенів Шевченківського райо...  8039100000
# 22437  Школа №199 І-ІІІ ступенів Шевченківського райо...  8039100000
# 22438  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
#
#                                                       id Код ЄДРПОУ url
# ...

# %%
opendatabot_links_new = []
for eoname in tqdm(unmatched_new['eoname']):
    opendatabot_links_new.append(search_opendatabot(eoname))
# Out:
# 100%|██████████| 14917/14917 [14:45:43<00:00,  3.56s/it]

# %%
opendatabot_df_new = pd.DataFrame(opendatabot_links_new)
opendatabot_df_new
# Out:
#                                                   eoname
# 0      Відокремлений структурний підрозділ «Вінницьки...  \
# 1      Відокремлений структурний підрозділ Вінницький...
# 2      Відокремлений структурний підрозділ Закладу ви...
# 3      Вінницька Установа виконання покарань Управлін...
# 4      Вінницька виправна колонія Управління Державно...
# ...                                                  ...
# 14912  Школа №163 І-ІІІ ступенів імені М.Кирпоноса Ше...
# 14913  Школа №169 І-ІІІ ступенів Шевченківського райо...
# 14914  Школа №175 І-ІІІ ступенів Шевченківського райо...
# 14915  Школа №199 І-ІІІ ступенів Шевченківського райо...
# 14916  Школа №25 І-ІІІ ступенів Шевченківського район...
#
#                                      url
# 0
# 1
# 2
# 3
# 4
# ...                                  ...
# 14912  https://opendatabot.ua/c/26125756
# 14913  https://opendatabot.ua/c/22881900
# 14914  https://opendatabot.ua/c/26125940
# 14915  https://opendatabot.ua/c/22881923
# 14916
# ...

# %%
unmatched_new

# %%
unmatched_link = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')
unmatched_link = unmatched_link.drop(columns = ['key_0'], axis=1)
unmatched_link.head()
# Out:
#                                               eoname KOATUU_2020
# 0  ВСП "Технологічно-промисловий фаховий коледж В...  0510100000  \
# 1             Вище професійне училище №11 м. Вінниці  0510100000
# 2  Вище художнє професійно-технічне училище №5 м....  0510100000
# 3  Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4  Відокремлений структурний підрозділ "Вінницьки...  0510100000
#
#                                                   id Код ЄДРПОУ
# 0  всптехнологчнопромисловийфаховийколеджвницьког...        NaN  \
# 1                       вищепрофесйнеучилище№11мвниц        NaN
# 2         вищехудожнєпрофесйнотехнчнеучилище№5мвниця        NaN
# 3  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
# 4  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
#
#                                url_x url_y
# 0  https://opendatabot.ua/c/00419667   NaN
# 1  https://opendatabot.ua/c/03065891   NaN
# 2  https://opendatabot.ua/c/02539890   NaN
# ...

# %%
unmatched_link.loc[unmatched_link['url_x'] == '', 'url_x'] = unmatched_link.loc[unmatched_link['url_x'] == '', 'url_y']
unmatched_link
# Out:
#                                                   eoname KOATUU_2020
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000  \
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 23745  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 23746  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 23747  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 23748  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 23749  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN  \
# ...

# %%
unmatched_link = unmatched_link.drop(columns=['url_y'], axis=1)
unmatched_link = unmatched_link.rename(columns = {'url_x':'url'})
unmatched_link

# %%
unmatched_link[unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
# Out:
#                                                   eoname KOATUU_2020
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000  \
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 23744  Школа №199 І-ІІІ ступенів Шевченківського райо...  8039100000
# 23746  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 23747  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 23748  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 23749  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN  \
# ...

# %%
unmatched_link.to_csv('unmatched_link.csv', index=False)

# %% [markdown]
# # Stop here

# %%
import pandas as pd

# %%
unmatched_link = pd.read_csv('schools_edrpou.csv', dtype=str)
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 27505  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 27506  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 27507  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 27508  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 27509  школа І-ІІІ ступенів №175 ім.В Марченка Шевчен...  8039100000
#
#                                        year KOATUU_2020_reg  \
# 0                                    [2022]              05
# ...

# %%
# additional 
unmatched_link = unmatched_link[unmatched_link['EDRPOU'].isna()]
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 5      Відокремлений структурний підрозділ «Вінницьки...  0510100000
# 8      Вінницька Установа виконання покарань Управлін...  0510100000
# 9      Вінницька виправна колонія Управління Державно...  0510100000
# 11     Вінницьке відділення Ірпінського державного ко...  0510100000
# ...                                                  ...         ...
# 27357  Середня загальноосвітня школа №279 імені Петра...  8038900000
# 27365  Середня загальноосвітня школа №69 Солом'янсько...  8038900000
# 27390  Технічний ліцей Національного технічного уніве...  8038900000
# 27479  Товариство з обмеженою відповідальністю "Франц...  8039100000
# 27501  Школа №163 І-ІІІ ступенів імені М.Кирпоноса Ше...  8039100000
#
#                                              year KOATUU_2020_reg  \
# 0                                          [2022]              05
# ...

# %%
unmatched_new = unmatched_link

# %%
unmatched_new = unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
unmatched_new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9c8f018134b8> in <module>
# ----> 1 unmatched_new = unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
#       2 unmatched_new
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'url'

# %%
opendatabot_links_new = []
for eoname in tqdm(unmatched_new['eoname']):
    opendatabot_links_new.append(search_opendatabot(eoname))
# Out:
# 100%|██████████| 3318/3318 [2:38:28<00:00,  2.87s/it]

# %%
opendatabot_df_new = pd.DataFrame(opendatabot_links_new)
opendatabot_df_new
# Out:
#                                                  eoname  \
# 0     ВСП "Технологічно-промисловий фаховий коледж В...
# 1     Відокремлений структурний підрозділ «Вінницьки...
# 2     Вінницька Установа виконання покарань Управлін...
# 3     Вінницька виправна колонія Управління Державно...
# 4     Вінницьке відділення Ірпінського державного ко...
# ...                                                 ...
# 3313  Середня загальноосвітня школа №279 імені Петра...
# 3314  Середня загальноосвітня школа №69 Солом'янсько...
# 3315  Технічний ліцей Національного технічного уніве...
# 3316  Товариство з обмеженою відповідальністю "Франц...
# 3317  Школа №163 І-ІІІ ступенів імені М.Кирпоноса Ше...
#
#                                     url
# 0     https://opendatabot.ua/c/00419667
# 1     https://opendatabot.ua/c/40397462
# 2     https://opendatabot.ua/c/08562602
# 3     https://opendatabot.ua/c/08562594
# 4     https://opendatabot.ua/c/35023972
# ...                                 ...
# ...

# %%
opendatabot_df_new[opendatabot_df_new.url!='']
# Out:
#                                                  eoname  \
# 0     ВСП "Технологічно-промисловий фаховий коледж В...
# 1     Відокремлений структурний підрозділ «Вінницьки...
# 2     Вінницька Установа виконання покарань Управлін...
# 3     Вінницька виправна колонія Управління Державно...
# 4     Вінницьке відділення Ірпінського державного ко...
# ...                                                 ...
# 3295  Генічеська загальноосвітня вечірня (змінна) шк...
# 3308  Середня загальноосвітня школа №328 - загальноо...
# 3309        Спеціалізована школа №181 імені Івана Кудрі
# 3310  Загальноосвітній навчальний заклад "Міжнародна...
# 3311  Гімназія біотехнологій №177 Солом'янського рай...
#
#                                     url
# 0     https://opendatabot.ua/c/00419667
# 1     https://opendatabot.ua/c/40397462
# 2     https://opendatabot.ua/c/08562602
# 3     https://opendatabot.ua/c/08562594
# 4     https://opendatabot.ua/c/35023972
# ...                                 ...
# ...

# %%
opendatabot_df_new[opendatabot_df_new.url!=''].to_csv('unmatched_link2.csv', index=False)

# %%
df = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')

df[~df.url_y.isnull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a30ab23b8580> in <module>
#       1 df = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')
#       2
# ----> 3 df[~df.url_y.isnull()]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'url_y'

# %%
unmatched_link = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')
unmatched_link = unmatched_link.drop(columns = ['key_0'], axis=1)
unmatched_link.head()
# Out:
#                                               eoname KOATUU_2020  \
# 0  ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1             Вище професійне училище №11 м. Вінниці  0510100000
# 2  Вище художнє професійно-технічне училище №5 м....  0510100000
# 3  Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4  Відокремлений структурний підрозділ "Вінницьки...  0510100000
#
#                                                   id Код ЄДРПОУ  \
# 0  всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# 1                       вищепрофесйнеучилище№11мвниц        NaN
# 2         вищехудожнєпрофесйнотехнчнеучилище№5мвниця        NaN
# 3  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
# 4  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
#
#                                url_x url_y
# 0  https://opendatabot.ua/c/00419667   NaN
# 1  https://opendatabot.ua/c/03065891   NaN
# 2  https://opendatabot.ua/c/02539890   NaN
# ...

# %%
unmatched_link.loc[unmatched_link['url_x'].isna(), 'url_x'] = ''

# %%
unmatched_link.loc[unmatched_link['url_x'] == '', 'url_x'] = unmatched_link.loc[unmatched_link['url_x'] == '', 'url_y']
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 22683  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 22684  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 22685  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 22686  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 22687  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ  \
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# ...

# %%
unmatched_link = unmatched_link.drop(columns=['url_y'], axis=1)
unmatched_link = unmatched_link.rename(columns = {'url_x':'url'})
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 22683  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 22684  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 22685  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 22686  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 22687  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ  \
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# ...

# %%
unmatched_link.drop_duplicates(inplace=True)

# %%
unmatched_link.reset_index(drop=True, inplace=True)

# %%
unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
# Out:
#                                                   eoname KOATUU_2020  \
# 10     Вінницьке відділення Ірпінського державного ко...  0510100000
# 11     Вінницьке відділення Ірпінського державного ко...  0510100000
# 13     Вінницький коледж Національного університету х...  0510100000
# 14     Вінницький коледж будівництва і архітектури Ки...  0510100000
# 16     Вінницький коледж економіки та підприємництва ...  0510100000
# ...                                                  ...         ...
# 22288  Спеціалізована школа №135 І-ІІІ ступенів з пог...  8039100000
# 22304  Товариство з обмеженою відповідальністю "Франц...  8039100000
# 22305                 Фаховий коледж Університету "КРОК"  8039100000
# 22306  Фаховий коледж бізнесу та аналітики Національн...  8039100000
# 22315  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
#
#                                                       id Код ЄДРПОУ url
# ...

# %%
unmatched_link1 = unmatched_link.copy()

# %%
unmatched_link.to_csv('unmatched_link1.csv',  index=False, encoding='utf-8')

# %%
schools_reg = schools_edrpou_id.merge(schools_data_id[['Код ЄДРПОУ']], left_on=[schools_edrpou_id['id']], right_on=[schools_data_id.id], how='left')
schools_reg = schools_reg.drop(columns = ['key_0'], axis=1)
schools_reg.head()

# %%
schools_reg[schools_reg['Код ЄДРПОУ'].notna()]

# %%
# sample 20% for check
unmatched_link[~unmatched_link.url.isna()].sample(4470).to_csv('unmatched_link_test_sample.csv', index=False)

# %% [markdown]
# # Youcontrol parser

# %%
#!pip install -U duckpy
from duckpy import Client
from tqdm import tqdm
import time
tqdm.pandas()

def search_youcontrol(school_name, max_retry=20):
    """
    Search for school in youcontrol.com.ua
    """
    client = Client()
    opendatabot_url = ''
    retry = 0
    while not opendatabot_url and retry < max_retry:
        try:
            results = client.search(school_name, limit=20)
        except:
            time.sleep(20)
            continue
        for site in results:
            if site['url'].startswith('https://youcontrol.com.ua/catalog/company_details/'):
                opendatabot_url = site['url']
                break
        retry += 1
    return {'eoname': school_name, "url": opendatabot_url}

search_youcontrol('ЄДРПОУ:'+'Вінницьке відділення Ірпінського державного коледжу економіки та права')
# Out:
# {'eoname': 'ЄДРПОУ:Вінницьке відділення Ірпінського державного коледжу економіки та права',
#  'url': ''}

# %%
unmatched_link = pd.read_csv('unmatched_link1.csv', dtype=str)
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 22315  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 22316  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 22317  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 22318  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 22319  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ  \
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# ...

# %%
unmatched_new = unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
unmatched_new
# Out:
#                                                   eoname KOATUU_2020  \
# 10     Вінницьке відділення Ірпінського державного ко...  0510100000
# 11     Вінницьке відділення Ірпінського державного ко...  0510100000
# 13     Вінницький коледж Національного університету х...  0510100000
# 14     Вінницький коледж будівництва і архітектури Ки...  0510100000
# 16     Вінницький коледж економіки та підприємництва ...  0510100000
# ...                                                  ...         ...
# 22288  Спеціалізована школа №135 І-ІІІ ступенів з пог...  8039100000
# 22304  Товариство з обмеженою відповідальністю "Франц...  8039100000
# 22305                 Фаховий коледж Університету "КРОК"  8039100000
# 22306  Фаховий коледж бізнесу та аналітики Національн...  8039100000
# 22315  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
#
#                                                       id Код ЄДРПОУ  url
# ...

# %%
opendatabot_links_new = []
for eoname in tqdm(unmatched_new['eoname']):
    opendatabot_links_new.append(search_youcontrol(eoname))
# Out:
# 100%|██████████| 3865/3865 [4:40:34<00:00,  4.36s/it]

# %%
opendatabot_df_new = pd.DataFrame(opendatabot_links_new)
opendatabot_df_new
# Out:
#                                                  eoname  \
# 0     Вінницьке відділення Ірпінського державного ко...
# 1     Вінницьке відділення Ірпінського державного ко...
# 2     Вінницький коледж Національного університету х...
# 3     Вінницький коледж будівництва і архітектури Ки...
# 4     Вінницький коледж економіки та підприємництва ...
# ...                                                 ...
# 3860  Спеціалізована школа №135 І-ІІІ ступенів з пог...
# 3861  Товариство з обмеженою відповідальністю "Франц...
# 3862                 Фаховий коледж Університету "КРОК"
# 3863  Фаховий коледж бізнесу та аналітики Національн...
# 3864  Школа №25 І-ІІІ ступенів Шевченківського район...
#
#                                     url
# 0
# 1
# 2
# 3
# 4
# ...                                 ...
# 3860  https://opendatabot.ua/c/26125779
# 3861
# 3862
# 3863
# 3864
#
# [3865 rows x 2 columns]

# %%
opendatabot_df_new[opendatabot_df_new.url!='']
# Out:
#                                                  eoname  \
# 69    Барська загальноосвітня школа I-III ступенів №...
# 84    Каришківська загальноосвітня школа I-III ступенів
# 100      Осіївська загальноосвітня школа I-III ступенів
# 101    П'ятківська загальноосвітня школа I-III ступенів
# 116   Комунальний заклад "Мізяківсько-Хутірський нав...
# ...                                                 ...
# 3775  Спеціалізована школа №210 загальноосвітній нав...
# 3789  Комунальний вищий навчальний заклад Київської ...
# 3790  Комунальний заклад вищої освіти Київської обла...
# 3804  Київське вище професійне училище будівництва і...
# 3860  Спеціалізована школа №135 І-ІІІ ступенів з пог...
#
#                                     url
# 69    https://opendatabot.ua/c/21724083
# 84    https://opendatabot.ua/c/13337801
# 100   https://opendatabot.ua/c/26228290
# 101   https://opendatabot.ua/c/26228278
# 116   https://opendatabot.ua/c/26242150
# ...                                 ...
# ...

# %%
df = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')

df[~df.url_y.isnull()]
# Out:
#                                                    key_0  \
# 10     Вінницьке відділення Ірпінського державного ко...
# 11     Вінницьке відділення Ірпінського державного ко...
# 13     Вінницький коледж Національного університету х...
# 14     Вінницький коледж будівництва і архітектури Ки...
# 16     Вінницький коледж економіки та підприємництва ...
# ...                                                  ...
# 22622  Спеціалізована школа №135 І-ІІІ ступенів з пог...
# 22638  Товариство з обмеженою відповідальністю "Франц...
# 22639                 Фаховий коледж Університету "КРОК"
# 22640  Фаховий коледж бізнесу та аналітики Національн...
# 22649  Школа №25 І-ІІІ ступенів Шевченківського район...
#
#                                                   eoname KOATUU_2020  \
# 10     Вінницьке відділення Ірпінського державного ко...  0510100000
# 11     Вінницьке відділення Ірпінського державного ко...  0510100000
# 13     Вінницький коледж Національного університету х...  0510100000
# ...

# %%
unmatched_link = unmatched_link.merge(opendatabot_df_new[['url']], left_on=[unmatched_link['eoname']], right_on=[opendatabot_df_new['eoname']], how='left')
unmatched_link = unmatched_link.drop(columns = ['key_0'], axis=1)
unmatched_link.head()
# Out:
#                                               eoname KOATUU_2020  \
# 0  ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1             Вище професійне училище №11 м. Вінниці  0510100000
# 2  Вище художнє професійно-технічне училище №5 м....  0510100000
# 3  Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4  Відокремлений структурний підрозділ "Вінницьки...  0510100000
#
#                                                   id Код ЄДРПОУ  \
# 0  всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# 1                       вищепрофесйнеучилище№11мвниц        NaN
# 2         вищехудожнєпрофесйнотехнчнеучилище№5мвниця        NaN
# 3  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
# 4  вдокремленийструктурнийпдроздлвницькийфаховийк...        NaN
#
#                                url_x url_y
# 0  https://opendatabot.ua/c/00419667   NaN
# 1  https://opendatabot.ua/c/03065891   NaN
# 2  https://opendatabot.ua/c/02539890   NaN
# ...

# %%
unmatched_link.loc[unmatched_link['url_x'].isna(), 'url_x'] = ''

# %%
unmatched_link.loc[unmatched_link['url_x'] == '', 'url_x'] = unmatched_link.loc[unmatched_link['url_x'] == '', 'url_y']
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 22649  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 22650  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 22651  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 22652  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 22653  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ  \
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# ...

# %%
unmatched_link = unmatched_link.drop(columns=['url_y'], axis=1)
unmatched_link = unmatched_link.rename(columns = {'url_x':'url'})
unmatched_link
# Out:
#                                                   eoname KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...  0510100000
# 1                 Вище професійне училище №11 м. Вінниці  0510100000
# 2      Вище художнє професійно-технічне училище №5 м....  0510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...  0510100000
# ...                                                  ...         ...
# 22649  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
# 22650  Школа №27 І-ІІІ ступенів Шевченківського район...  8039100000
# 22651  Школа №70 І-ІІІ ступенів Шевченківського район...  8039100000
# 22652  Школа №95 І-ІІІ ступенів Шевченківського район...  8039100000
# 22653  Лучицький навчально-виховний комплекс "Загальн...         NaN
#
#                                                       id Код ЄДРПОУ  \
# 0      всптехнологчнопромисловийфаховийколеджвницьког...        NaN
# ...

# %%
unmatched_link.drop_duplicates(inplace=True)

# %%
unmatched_link.reset_index(drop=True, inplace=True)

# %%
unmatched_link[~unmatched_link.url.apply(lambda x: isinstance(x, str) and len(x.strip())> 0)]
# Out:
#                                                   eoname KOATUU_2020  \
# 10     Вінницьке відділення Ірпінського державного ко...  0510100000
# 11     Вінницьке відділення Ірпінського державного ко...  0510100000
# 13     Вінницький коледж Національного університету х...  0510100000
# 14     Вінницький коледж будівництва і архітектури Ки...  0510100000
# 16     Вінницький коледж економіки та підприємництва ...  0510100000
# ...                                                  ...         ...
# 22283  Коледж мистецтв та дизайну Київського націонал...  8039100000
# 22310  Товариство з обмеженою відповідальністю "Франц...  8039100000
# 22311                 Фаховий коледж Університету "КРОК"  8039100000
# 22312  Фаховий коледж бізнесу та аналітики Національн...  8039100000
# 22321  Школа №25 І-ІІІ ступенів Шевченківського район...  8039100000
#
#                                                       id Код ЄДРПОУ url
# ...

# %%
unmatched_link1 = unmatched_link.copy()

# %%
unmatched_link.to_csv('unmatched_link1.csv',  index=False, encoding='utf-8')

# %% [markdown]
# # One school on KOATUU_2020

# %%
# where one school on KOATUU_2020
df_one = unmatched.drop(columns=['id','Код ЄДРПОУ']).reset_index(drop=True)
df_one.head()

# %%
schools_data_one = schools_data_id.groupby(by=['Код КОАТУУ']).agg(
    {
        "Повна назва": lambda x: len(x.unique()),
    }
).reset_index()

schools_data_one = pd.DataFrame(schools_data_one[schools_data_one['Повна назва'] == 1]['Код КОАТУУ'])
schools_data_one.head()

# %%
schools_data_one = schools_data_one.merge(schools_data_id, on='Код КОАТУУ', how='inner')

# %%
schools_data_one = schools_data_one[['Код КОАТУУ', 'Повна назва', 'Код ЄДРПОУ']]
schools_data_one.head()

# %%
df_one = df_one.merge(schools_data_one, how='inner', left_on='KOATUU_2020', right_on='Код КОАТУУ')
df_one = df_one.drop(columns=['Код КОАТУУ'])
df_one

# %%
# save
df_one.to_csv('school_one_fuzzymatch.csv', index=False)

# %% [markdown]
# # Match unmatched schools with schools

# %%
df = pd.read_csv('unmatched_schools_edrpou_bot.csv')
df.head()
# Out:
#                                               eoname  KOATUU_2020  \
# 0  ВСП "Технологічно-промисловий фаховий коледж В...    510100000
# 1             Вище професійне училище №11 м. Вінниці    510100000
# 2  Вище художнє професійно-технічне училище №5 м....    510100000
# 3  Відокремлений структурний підрозділ «Вінницьки...    510100000
# 4  Відокремлений структурний підрозділ Вінницький...    510100000
#
#                              year  \
# 0                          [2022]
# 1  [2018, 2019, 2020, 2021, 2022]
# 2  [2018, 2019, 2020, 2021, 2022]
# 3                          [2022]
# 4                    [2021, 2022]
#
#                                                   id  EDRPOU  KOATUU_2020_reg
# 0  вдокремленийструктурнийпдроздлтехнологчнопроми...     NaN                5
# 1                        вищепрофесйнеучилище11мвниц     NaN                5
# 2          вищехудожнєпрофесйнотехнчнеучилище5мвниця     NaN                5
# ...

# %%
df.shape
# Out:
# (8188, 6)

# %%
df = df[df['Код ЄДРПОУ'].isna()]
df = df.drop(columns=['Код ЄДРПОУ'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Код ЄДРПОУ'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_link = pd.read_csv('unmatched_link1.csv')
df_link = df_link[:22325] # delete bad row without KOATUU_2020

# %%
df_link['KOATUU_2020'] = df_link['KOATUU_2020'].astype(int)
df_link
# Out:
#                                                   eoname  KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...    510100000
# 1                 Вище професійне училище №11 м. Вінниці    510100000
# 2      Вище художнє професійно-технічне училище №5 м....    510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...    510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...    510100000
# ...                                                  ...          ...
# 22320  Школа №199 І-ІІІ ступенів Шевченківського райо...   8039100000
# 22321  Школа №25 І-ІІІ ступенів Шевченківського район...   8039100000
# 22322  Школа №27 І-ІІІ ступенів Шевченківського район...   8039100000
# 22323  Школа №70 І-ІІІ ступенів Шевченківського район...   8039100000
# 22324  Школа №95 І-ІІІ ступенів Шевченківського район...   8039100000
#
#                                                       id  Код ЄДРПОУ  \
# ...

# %%
df_link = df_link[df_link['url'].notna()]
df_link
# Out:
#                                                   eoname  KOATUU_2020  \
# 0      ВСП "Технологічно-промисловий фаховий коледж В...    510100000
# 1                 Вище професійне училище №11 м. Вінниці    510100000
# 2      Вище художнє професійно-технічне училище №5 м....    510100000
# 3      Відокремлений структурний підрозділ "Вінницьки...    510100000
# 4      Відокремлений структурний підрозділ "Вінницьки...    510100000
# ...                                                  ...          ...
# 22319  Школа №175 І-ІІІ ступенів Шевченківського райо...   8039100000
# 22320  Школа №199 І-ІІІ ступенів Шевченківського райо...   8039100000
# 22322  Школа №27 І-ІІІ ступенів Шевченківського район...   8039100000
# 22323  Школа №70 І-ІІІ ступенів Шевченківського район...   8039100000
# 22324  Школа №95 І-ІІІ ступенів Шевченківського район...   8039100000
#
#                                                       id  Код ЄДРПОУ  \
# ...

# %%
df_new = df.merge(df_link[['eoname', 'KOATUU_2020','url']], left_on=['eoname', 'KOATUU_2020'], right_on=['eoname', 'KOATUU_2020'], how='inner').drop_duplicates()

# %%
len(df[['eoname','KOATUU_2020']].drop_duplicates()), len(df['eoname'])
# Out:
# (8188, 8188)

# %%
df_new[df_new.duplicated(subset=['eoname','KOATUU_2020'], keep=False)]
# Out:
#                                                  eoname  KOATUU_2020  \
# 451   Загальноосвітня школа І-ІІІ ступеня с. Городищ...    722880706
# 452   Загальноосвітня школа І-ІІІ ступеня с. Городищ...    722880706
# 454   Загальноосвітня школа І-ІІІ ступеня с. Городищ...    722881701
# 455   Загальноосвітня школа І-ІІІ ступеня с. Городищ...    722881701
# 877   Мар'ївська загальноосвітня школа І-ІІІ ступені...   1225283304
# ...                                                 ...          ...
# 4419  Кременецька загальноосвітня школа - інтернат І...   6123486202
# 4539  І-Іванівська загальноосвітня школа I-III ступе...   6320481504
# 4540  І-Іванівська загальноосвітня школа I-III ступе...   6320481504
# 4542  І-Іванівська загальноосвітня школа I-III ступе...   6320483501
# 4543  І-Іванівська загальноосвітня школа I-III ступе...   6320483501
#
#                                       year  \
# 451                                 [2016]
# 452                                 [2016]
# ...

# %%
13977+67
# Out:
# 14044

# %%
df_new.to_csv('unm_schools_with_links.csv', index=False)

# %%
schools_edrpou_loc = schools_edrpou.merge(locations[['KOATUU_2020']], left_on=[schools_edrpou['eoregname'],schools_edrpou['eoareaname'], schools_edrpou['eotername']], right_on=[locations['regname'],locations['areaname'], locations['tername']], how='left')
schools_edrpou_loc = schools_edrpou_loc.drop(columns = ['key_0', 'key_1', 'key_2'], axis=1)
