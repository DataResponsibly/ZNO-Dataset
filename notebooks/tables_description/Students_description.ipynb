# %% [markdown]
# # Description of `Students` table

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../tables_creation/final_tables/students.csv', dtype = str)
df.head()
# Out:
#                                   outid birth sextypename classprofilename  \
# 0  a99c6c63-aa70-4aec-ba42-370f7261e857  1998        Male              NaN
# 1  c3136421-569e-422e-ae8f-41c4c931fd70  1998      Female              NaN
# 2  30de395e-7a74-452a-8370-6856d240fbfb  1999        Male              NaN
# 3  852ca6ab-7fbd-40ad-ae51-39dc94edc9e1  1999      Female              NaN
# 4  bc9b70ca-c091-440f-b1de-f04b308f3a54  1999        Male              NaN
#
#   classlangname KOATUU_2020 EDRPOU_school
# 0           NaN  2323085101      26373098
# 1           NaN  6822710100      25880114
# 2           NaN  7310100000      21431046
# 3           NaN  1411700000      25705061
# 4           NaN  6110100000      14040173

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2490052 entries, 0 to 2490051
# Data columns (total 7 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   outid             object
#  1   birth             object
#  2   sextypename       object
#  3   classprofilename  object
#  4   classlangname     object
#  5   KOATUU_2020       object
#  6   EDRPOU_school     object
# dtypes: object(7)
# memory usage: 133.0+ MB

# %%
# print unique values for each column
for col in df.columns:
    print('Unique length in ', col+':\t', len(df[col].unique()))
# Out:
# Unique length in  outid:	 2490052
# Unique length in  birth:	 63
# Unique length in  sextypename:	 2
# Unique length in  classprofilename:	 28
# Unique length in  classlangname:	 8
# Unique length in  KOATUU_2020:	 18470
# Unique length in  EDRPOU_school:	 12879

# %%
plt.figure(figsize=(15,8))
plot = sns.countplot(df, x="birth")
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
None
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_12442/3073966906.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
plot = sns.countplot(df, x="sextypename")
None

# %%
df['sextypename'].value_counts()
# Out:
# sextypename
# Female    1265305
# Male      1224747
# Name: count, dtype: int64

# %%
plot = sns.countplot(df, x="classprofilename", order = df['classprofilename'].value_counts().index)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
None
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_12442/1220839803.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
df['classprofilename'].value_counts()
# Out:
# classprofilename
# Universal                                  239443
# Junior specialist                          227506
# Ukrainian philology                        218325
# Skilled worker                             147912
# Foreign philology                          112719
# Mathematics                                 77652
# Technology                                  57675
# History                                     50561
# Other (multi-profile)                       37815
# Information technology                      35810
# Інший                                       24024
# Biology and chemistry                       23581
# Physics and mathematics                     23570
# Economics                                   17478
# Law                                         15398
# Military and sports                         11990
# Sports                                      11183
# Biotechnology                                8651
# Ecology                                      7443
# Biology                                      6953
# Geography                                    6295
# Art and aesthetics                           5305
# Physics                                      1415
# Chemical technologies and agrochemistry      1355
# Biology and physics                          1353
# Philosophy                                    460
# Physics and chemistry                         198
# Name: count, dtype: int64

# %%
plot = sns.countplot(df, x="classlangname", order = df['classlangname'].value_counts().index)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
None
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_12442/4278837018.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
df['classlangname'].value_counts()
# Out:
# classlangname
# Ukrainian    1289672
# Russian        72454
# Romanian        4915
# Hungarian       3644
# Moldovan         832
# Polish           461
# Other             92
# Name: count, dtype: int64

# %% [markdown]
# Features:
# - outid (Student ID): 2490052 unique students identifiers
# - birth: year of student's birth. Range of values:
#     - 1944-2010 (integer)
# - sextypename: sex of student. Range of values:
#     - чоловіча: male
#     - жіноча: female
# - classprofilename: class profile. Range of values:
#     - Універсальний: Universal
#     - Молодший спеціаліст: Junior Specialist
#     - Української філології: Ukrainian Philology
#     - Кваліфікований робітник: Qualified Worker
#     - Іноземної філології: Foreign philology
#     - Математичний: Mathematical
#     - Технологічний: Technological
#     - Історичний: Historical
#     - Інший(багатопрофільність): Other (multi-profile)
#     - Інформаційно-технологічний: Information technology
#     - Інший: Other
#     - Біолого-хімічний: Biological and chemical
#     - Фізико-математичний: Physical and mathematical
#     - Економічний: Economic
#     - Правовий: Legal
#     - Військово-спортивний: Military and sports
#     - Спортивний: Sports
#     - Біотехнологічний: Biotechnological
#     - Екологічний: Ecological
#     - Біологічний: Biological
#     - Географічний: Geographical
#     - Художньо-естетичний: Artistic and aesthetic
#     - Фізичний: Physical
#     - Хіміко-технологічний та агрохімічний: Chemical-technological and agrochemical
#     - Біолого-фізичний: Biological and physical
#     - Філософський: Philosophical
#     - Фізико-хімічний: Physico-chemical
# - classlangname: language of class. Range of values:
#     - українська: Ukrainian
#     - російська: russian
#     - румунська: Romanian
#     - угорська: Hungarian
#     - молдовська: Moldovan
#     - польська: Polish
#     - інша: Other
# - KOATUU_2020 (KOATUU code): 18470 unique codes, denoting schools locations (a unique digital code for each administrative-territorial entity of Ukraine, used from January 1998 till January 2021)
# - EDRPOU (unique code of the legal entity or physical person): 12879 unique codes of schools.
