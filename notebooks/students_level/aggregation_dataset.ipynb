# %%
import pandas as pd

# %%
df_preprocessed = pd.read_csv("eie_full_translated.csv")
# Out:
# /var/folders/cz/wq9d8j_11fx3b8pjjbk7z8br0000gn/T/ipykernel_6964/4281629353.py:1: DtypeWarning: Columns (74,75,77,78,79,80,88,89,91,92,93,94,95,96,98,99,100,101,105,106,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_preprocessed = pd.read_csv("eie_full_translated.csv")

# %%
df_preprocessed
# Out:
#                                         outid sextypename
# 0        a99c6c63-aa70-4aec-ba42-370f7261e857        Male  \
# 1        c3136421-569e-422e-ae8f-41c4c931fd70      Female
# 2        fbd0e280-4b77-4f34-942d-00bc850c2992      Female
# 3        30de395e-7a74-452a-8370-6856d240fbfb        Male
# 4        52a40c74-374e-4744-bd6f-938ab7a4a641        Male
# ...                                       ...         ...
# 1967009  e62710ee-74fa-4085-b066-f38fc37ceae7      Female
# 1967010  b2e4de44-7ebd-4163-8952-f988a9de1f67      Female
# 1967011  e007c190-1fe1-4658-9eb0-f7cf489fc015      Female
# 1967012  2668b9f3-ddf9-4062-acd7-fdf6e2ca8cc8        Male
# 1967013  c0723de9-57b5-4450-b404-ffe67945d843      Female
#
#                        regname                areaname
# 0          Zaporizhzhia Oblast      Melitopol district  \
# 1          Khmelnytskyi Oblast   Krasylivskyi district
# 2        Dnipropetrovsk Oblast  Petropavlovsk district
# 3            Chernivtsi Oblast              Chernivtsi
# 4              Mykolaiv Oblast    Vradiivskyi district
# ...                        ...                     ...
# 1967009           Rivne Oblast     Demydivsky district
# 1967010         Kharkiv Oblast       Kegichiv district
# 1967011           Odesa Oblast            Odesa region
# 1967012       Vinnytsia Oblast      Haysynsky district
# 1967013    Khmelnytskyi Oblast     Khmelnytskyi region
#
#                                   tername
# 0                             s. Patience  \
# 1                    the city of Krasiliv
# 2                       Dmytrivka village
# 3        Shevchenkiv district of the city
# 4                          Kumari village
# ...                                   ...
# 1967009                 Demydivka village
# 1967010                Kegichivka village
# 1967011             Bilhorod-Dnistrovskyi
# 1967012               Chechelivka village
# 1967013                        m. Slavuta
#
#                                                regtypename
# 0        A graduate of an Ukrainian school of the curre...  \
# 1        A graduate of an Ukrainian school of the curre...
# 2             A graduate of a school of the previous years
# 3        A graduate of an Ukrainian school of the curre...
# 4        College student of a vocational or higher educ...
# ...                                                    ...
# 1967009  College student of a vocational or higher educ...
# 1967010  College student of a vocational or higher educ...
# 1967011  College student of a vocational or higher educ...
# 1967012  A graduate of an Ukrainian school of the curre...
# 1967013  A graduate of an Ukrainian school of the curre...
#
#                                                     eoname
# 0        Terpinniv Collegium "Zherelo" of the Melitopol...  \
# 1        Krasyliv secondary school of grades I-III No. ...
# 2                                                      NaN
# 3        Chernivtsi specialized school of the I-III deg...
# 4                                                      NaN
# ...                                                    ...
# 1967009  Higher vocational school No. 25, Demydivka vil...
# 1967010  Vocational and technical school No. 60, Kegich...
# 1967011            OKU "Bilhorod-Dniester Medical College"
# 1967012  Secondary comprehensive school of grades I-III...
# 1967013  Slavut educational and educational complex "Sp...
#
#                                                 eotypename
# 0                                                Collegium  \
# 1                       Secondary general education school
# 2                                                      NaN
# 3                                       Specialized school
# 4                                                      NaN
# ...                                                    ...
# 1967009                Institution of vocational education
# 1967010                Institution of vocational education
# 1967011  Institution of professional preliminary higher...
# 1967012                 Secondary general education school
# 1967013                                 Specialized school
#
#                    eoregname             eoareaname  ... ukradaptscale
# 0        Zaporizhzhia Oblast     Melitopol district  ...           NaN  \
# 1        Khmelnytskyi Oblast  Krasylivskyi district  ...           NaN
# 2                        NaN                    NaN  ...           NaN
# 3          Chernivtsi Oblast             Chernivtsi  ...           NaN
# 4                        NaN                    NaN  ...           NaN
# ...                      ...                    ...  ...           ...
# 1967009         Rivne Oblast    Demydivsky district  ...           0.0
# 1967010       Kharkiv Oblast      Kegichiv district  ...           NaN
# 1967011         Odesa Oblast  Bilhorod-Dnistrovskyi  ...           NaN
# 1967012     Vinnytsia Oblast     Haysynsky district  ...           0.0
# 1967013  Khmelnytskyi Oblast             m. Slavuta  ...           0.0
#
#         Degree of institution Number of full-time teaching staff in total
# 0                         NaN                                         NaN  \
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
# ...                       ...                                         ...
# 1967009                   NaN                                         NaN
# 1967010                   NaN                                         NaN
# 1967011                   NaN                                         NaN
# 1967012                   NaN                                         NaN
# 1967013                   NaN                                         NaN
#
#         Number of full-time non-teaching staff in total
# 0                                                   NaN  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1967009                                             NaN
# 1967010                                             NaN
# 1967011                                             NaN
# 1967012                                             NaN
# 1967013                                             NaN
#
#          Number of full-time teaching staff of retirement age
# 0                                                      NaN     \
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1967009                                                NaN
# 1967010                                                NaN
# 1967011                                                NaN
# 1967012                                                NaN
# 1967013                                                NaN
#
#         Number of students in total Number of classes in total
# 0                               NaN                        NaN  \
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 1967009                         NaN                        NaN
# 1967010                         NaN                        NaN
# 1967011                         NaN                        NaN
# 1967012                         NaN                        NaN
# 1967013                         NaN                        NaN
#
#         Total number of students and children receiving preschool education
# 0                                                      NaN                   \
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1967009                                                NaN
# 1967010                                                NaN
# 1967011                                                NaN
# 1967012                                                NaN
# 1967013                                                NaN
#
#         Expenditures for the operation of the institution (general fund), UAH thousand (cash expenditures)
# 0                                                      NaN                                                  \
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1967009                                                NaN
# 1967010                                                NaN
# 1967011                                                NaN
# 1967012                                                NaN
# 1967013                                                NaN
#
#         Expenditures for the operation of the institution (general fund), UAH thousand (plan)
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1967009                                                NaN
# 1967010                                                NaN
# 1967011                                                NaN
# 1967012                                                NaN
# 1967013                                                NaN
#
# [1967014 rows x 128 columns]

# %%
df_preprocessed.classprofilename.unique()
# Out:
# array([nan, 'Physics and mathematics', 'History', 'Universal',
#        'Ukrainian philology', 'Foreign philology',
#        'Information technology', 'Other (multi-profile)', 'Mathematics',
#        'Ecology', 'Economics', 'Technology', 'Geography',
#        'Biology and chemistry', 'Sports', 'Physics',
#        'Military and sports', 'Art and aesthetics', 'Law',
#        'Biotechnology', 'Chemical technologies and agrochemistry',
#        'Biology and physics', 'Philosophy', 'Physics and chemistry',
#        'Інший(багатопрофільність)', 'Biology', 'Junior specialist',
#        'Skilled worker'], dtype=object)

# %%
orig_df = df_preprocessed.drop(['outid', 'regname', 'areaname', 'tername', 'regtypename', 'tertypename', 
                                'ukrptname', 'ukrptregname', 'ukrptareaname', 'ukrpttername',
                                'histptname', 'histptregname', 'histptareaname', 'histpttername',
                                'mathptname', 'mathptregname', 'mathptareaname', 'mathpttername',
                                'physptname', 'physptregname', 'physptareaname', 'physpttername',
                                'chemptname', 'chemptregname', 'chemptareaname', 'chempttername',
                                'bioptname', 'bioptregname', 'bioptareaname', 'biopttername',
                                'geoptname', 'geoptregname', 'geoptareaname', 'geopttername',
                                'engptname', 'engptregname', 'engptareaname', 'engpttername',
                                'fraptname', 'fraptregname', 'fraptareaname', 'frapttername', 
                                'deuptname', 'deuptregname', 'deuptareaname', 'deupttername',
                                'spaptname', 'spaptregname', 'spaptareaname', 'spapttername',
                                 'rusptname', 'rusptregname', 'rusptareaname', 'ruspttername'], axis=1)

# %%
orig_df.columns
# Out:
# Index(['sextypename', 'eoname', 'eotypename', 'eoregname', 'eoareaname',
#        'eotername', 'eoparent', 'ukrtest', 'ukrteststatus', 'ukrball100',
#        'histtest', 'histlang', 'histteststatus', 'histball100', 'mathtest',
#        'mathlang', 'mathteststatus', 'mathball100', 'phystest', 'physlang',
#        'physteststatus', 'physball100', 'chemtest', 'chemlang',
#        'chemteststatus', 'chemball100', 'biotest', 'biolang', 'bioteststatus',
#        'bioball100', 'geotest', 'geolang', 'geoteststatus', 'geoball100',
#        'engtest', 'engteststatus', 'engball100', 'fratest', 'frateststatus',
#        'fraball100', 'deutest', 'deuteststatus', 'deuball100', 'spatest',
#        'spateststatus', 'spaball100', 'rustest', 'rusteststatus', 'rusball100',
#        'year', 'age', 'classprofilename', 'classlangname', 'ukrball',
#        'histball', 'mathball', 'physball', 'chemball', 'bioball', 'geoball',
#        'engball', 'fraball', 'deuball', 'spaball', 'ukradaptscale',
#        'Degree of institution', 'Number of full-time teaching staff in total',
#        'Number of full-time non-teaching staff in total',
#        'Number of full-time teaching staff of retirement age',
#        'Number of students in total', 'Number of classes in total',
#        'Total number of students and children receiving preschool education',
#        'Expenditures for the operation of the institution (general fund), UAH thousand (cash expenditures)',
#        'Expenditures for the operation of the institution (general fund), UAH thousand (plan)'],
#       dtype='object')

# %%
orig_df["sexM"] = (orig_df["sextypename"] == "чоловіча").astype(int)
orig_df["sexF"] = (orig_df["sextypename"] == "жіноча").astype(int)

# %%
orig_df.classprofilename = orig_df.classprofilename.replace('Інший(багатопрофільність)', 'Інший')
