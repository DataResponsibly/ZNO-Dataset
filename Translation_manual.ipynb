# %%
import pandas as pd

# %%
from dictionaries_translation import *

# %%
zno_translated = pd.read_csv('translated.csv')
zno_translated
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8776\1888921137.py:1: DtypeWarning: Columns (83,84,85,86,87,88,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   zno_translated = pd.read_csv('translated.csv')
#                                         outid  birth sextypename  \
# 0        a4e039d0-07ef-4a3d-820d-106dcaf01b96   2001    чоловіча
# 1        c1fa1ed0-d2af-4964-9a88-3c138008304b   2001      жіноча
# 2        6504a7f3-7dfd-4a64-a2d9-4d49f5021303   2000      жіноча
# 3        5cbcd343-2e63-48b8-b36d-48797a76be31   2000    чоловіча
# 4        063c6498-7345-492c-b567-174938bac671   1999    чоловіча
# ...                                       ...    ...         ...
# 1458117  e62710ee-74fa-4085-b066-f38fc37ceae7   2003      жіноча
# 1458118  b2e4de44-7ebd-4163-8952-f988a9de1f67   1989      жіноча
# 1458119  e007c190-1fe1-4658-9eb0-f7cf489fc015   2004      жіноча
# 1458120  2668b9f3-ddf9-4062-acd7-fdf6e2ca8cc8   2004    чоловіча
# ...

# %%
zno_translated["sextypename"] = zno_translated["sextypename"].replace(sex_type_dict)

# %%
zno_translated["classprofilename"] = zno_translated["classprofilename"].replace(class_profile_dict)

# %%
zno_translated["classlangname"] = zno_translated["classlangname"].replace(lang_dict)
zno_translated["histlang"] = zno_translated["histlang"].replace(lang_dict)
zno_translated["mathlang"] = zno_translated["mathlang"].replace(lang_dict)
zno_translated["physlang"] = zno_translated["physlang"].replace(lang_dict)
zno_translated["chemlang"] = zno_translated["chemlang"].replace(lang_dict)
zno_translated["biolang"] = zno_translated["biolang"].replace(lang_dict)
zno_translated["geolang"] = zno_translated["geolang"].replace(lang_dict)

# %%
zno_translated["regname"] = zno_translated["regname"].replace(region_dict)
zno_translated["eoregname"] = zno_translated["eoregname"].replace(region_dict)
zno_translated["ukrptregname"] = zno_translated["ukrptregname"].replace(region_dict)
zno_translated["histptregname"] = zno_translated["histptregname"].replace(region_dict)
zno_translated["mathptregname"] = zno_translated["mathptregname"].replace(region_dict)
zno_translated["physptregname"] = zno_translated["physptregname"].replace(region_dict)
zno_translated["chemptregname"] = zno_translated["chemptregname"].replace(region_dict)
zno_translated["bioptregname"] = zno_translated["bioptregname"].replace(region_dict)
zno_translated["geoptregname"] = zno_translated["geoptregname"].replace(region_dict)
zno_translated["engptregname"] = zno_translated["engptregname"].replace(region_dict)
zno_translated["deuptregname"] = zno_translated["deuptregname"].replace(region_dict)
zno_translated["fraptregname"] = zno_translated["fraptregname"].replace(region_dict)
zno_translated["spaptregname"] = zno_translated["spaptregname"].replace(region_dict)

# %%
zno_translated["regtypename"] = zno_translated["regtypename"].replace(grad_type_dict)

# %%
zno_translated["eotypename"] = zno_translated["eotypename"].replace(school_type_dict)

# %%
zno_translated["tertypename"] = zno_translated["tertypename"].replace(settlment_type_dict)

# %%
zno_translated["ukrtest"] = zno_translated["ukrtest"].replace(tests_dict)
zno_translated["histtest"] = zno_translated["histtest"].replace(tests_dict)
zno_translated["mathtest"] = zno_translated["mathtest"].replace(tests_dict)
zno_translated["phystest"] = zno_translated["phystest"].replace(tests_dict)
zno_translated["chemtest"] = zno_translated["chemtest"].replace(tests_dict)
zno_translated["biotest"] = zno_translated["biotest"].replace(tests_dict)
zno_translated["geotest"] = zno_translated["geotest"].replace(tests_dict)
zno_translated["engtest"] = zno_translated["engtest"].replace(tests_dict)
zno_translated["deutest"] = zno_translated["deutest"].replace(tests_dict)
zno_translated["fratest"] = zno_translated["fratest"].replace(tests_dict)
zno_translated["spatest"] = zno_translated["spatest"].replace(tests_dict)

# %%
zno_translated["ukrteststatus"] = zno_translated["ukrteststatus"].replace(test_status_dict)
zno_translated["histteststatus"] = zno_translated["histteststatus"].replace(test_status_dict)
zno_translated["mathteststatus"] = zno_translated["mathteststatus"].replace(test_status_dict)
zno_translated["physteststatus"] = zno_translated["physteststatus"].replace(test_status_dict)
zno_translated["chemteststatus"] = zno_translated["chemteststatus"].replace(test_status_dict)
zno_translated["bioteststatus"] = zno_translated["bioteststatus"].replace(test_status_dict)
zno_translated["geoteststatus"] = zno_translated["geoteststatus"].replace(test_status_dict)
zno_translated["engteststatus"] = zno_translated["engteststatus"].replace(test_status_dict)
zno_translated["deuteststatus"] = zno_translated["deuteststatus"].replace(test_status_dict)
zno_translated["frateststatus"] = zno_translated["frateststatus"].replace(test_status_dict)
zno_translated["spateststatus"] = zno_translated["spateststatus"].replace(test_status_dict)

# %%
zno_translated["engdpalevel"] = zno_translated["engdpalevel"].replace(dpa_level_dict)
zno_translated["fradpalevel"] = zno_translated["fradpalevel"].replace(dpa_level_dict)
zno_translated["deudpalevel"] = zno_translated["deudpalevel"].replace(dpa_level_dict)
zno_translated["spadpalevel"] = zno_translated["spadpalevel"].replace(dpa_level_dict)
